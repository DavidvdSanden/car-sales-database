# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from supabase import create_client, Client
from tqdm import tqdm
import json
import time
import logging
import os
from dotenv import load_dotenv
from rich.console import Console
from rich.progress import Progress, BarColumn, TextColumn, TimeRemainingColumn
from datetime import datetime
import re

# %%
# Load variables from .env into the environment
load_dotenv()

# Read variables
supabase_url = os.getenv("SUPABASE_URL")
supabase_key = os.getenv("SUPABASE_KEY")

# %%
# Initialize client
supabase: Client = create_client(supabase_url, supabase_key)

# %%
table_name = "autoscout_car_adverts"

# %%
response = supabase.table(table_name).select("*").limit(1).execute()

# %%
response
# Out:
# APIResponse[~_ReturnT](data=[{'id': 77546, 'car_id': '68936f70-81e9-4387-ad5c-ac6eed1f5438', 'scraped_at': '2025-08-12T12:59:52.134215', 'make': 'nissan', 'model': 'qashqai', 'fuel_type': '2', 'first_registration': '03-2023', 'mileage': 48072, 'post_code_raw': '8281 PC', 'listing_price': 28695, 'post_code': '8281PC', 'transmission': None, 'fuel_text': None, 'power_text': None, 'power_kw': None, 'power_pk': None, 'model_type': None, 'model_text': None, 'range_raw': None, 'range_general': None, 'range_urban': None}], count=None)

# %%
response.data
# Out:
# [{'id': 77546,
#   'car_id': '68936f70-81e9-4387-ad5c-ac6eed1f5438',
#   'scraped_at': '2025-08-12T12:59:52.134215',
#   'make': 'nissan',
#   'model': 'qashqai',
#   'fuel_type': '2',
#   'first_registration': '03-2023',
#   'mileage': 48072,
#   'post_code_raw': '8281 PC',
#   'listing_price': 28695,
#   'post_code': '8281PC',
#   'transmission': None,
#   'fuel_text': None,
#   'power_text': None,
#   'power_kw': None,
#   'power_pk': None,
#   'model_type': None,
#   'model_text': None,
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None}]

# %% [markdown]
# ## Scraping

# %%
base_url = "https://www.autoscout24.nl/lst"

# %%
params = {
    "atype": "C",
    "cy": "NL",
    "damaged_listing": "exclude",
    "desc": "1",
    "powertype": "kw",
    "sort": "age",
    "source": "homepage_search-mask",
    "ustate": "N,U",
    "kmfrom":0,
    "kmto":1000,
    "pricefrom":0,
    "priceto":10000,
    "page": 1  # start page
}

# %%
price_vec = np.array(
        [0, 500, 650, 700, 750, 850, 1000, 1100, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 4000, 4500,
         5000, 5500, 6000, 6500, 7000, 7500, 8000, 8500, 9000, 9500, 10000, 10500, 11000, 11500, 12000, 12500, 13000,
         13500, 14000, 14500, 15000, 15500, 16000, 16500, 17000, 17500, 18000, 18500, 19000, 19500, 20000, 20500, 21000,
         21500, 22000, 22500, 23000, 24000, 24500, 25000, 26000, 27000, 28000, 28500, 29000, 30000, 31000, 32000, 33000,
         34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000,
         50000, 52000, 54000, 56000, 58000, 60000, 62000, 64000, 66000, 68000, 70000, 75000, 80000, 85000, 90000, 95000,
         100000, 150000, 1e9])
km_vec = np.array(
        [0, 1, 2, 5, 10, 15, 20, 50, 100, 200, 500, 1000, 2000, 3000, 5000, 10000, 15000, 20000, 25000, 30000, 35000,
response = supabase.table(table_name).select("car_id").execute()
car_ids_in_database = {d['car_id'] for d in response.data}
print(f"Found {len(car_ids_in_database)} existing car IDs.")
# Out:
# Fetching existing car IDs from the database...
# Found 268576 existing car IDs.

# %%
# Get current date and time
now = datetime.now()

# Format it as YYYY-MM-DD_HH-MM-SS
timestamp = now.strftime("%Y-%m-%d_%H-%M-%S")

# The level is set to INFO, so all messages from INFO and above will be recorded.
logging.basicConfig(filename=f"../logging/script_log_{timestamp}.log", level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')
logging.info('Script started.')

# Initialize a rich Console object
console = Console()

# IMPORTANT: if is_processing
is_processing_all = 1

# --- Main Loops ---
# Custom Progress display
with Progress(
    TextColumn("[progress.description]{task.description}"),
    BarColumn(),
    TextColumn("[progress.percentage]{task.percentage:>3.0f}%"),
    TimeRemainingColumn(),
    console=console
) as progress:
    
    # Outer loop over price range
    task_price = progress.add_task(
        "[green]Processing price ranges...", total=len(price_vec[:-1]-1)
    )

    for k, price in enumerate(price_vec[:-1]):
        params['pricefrom'] = round(price_vec[k])
        params['priceto'] = round(price_vec[k+1])

        if k % refresh_rate_cars_in_database == 0:
            response = supabase.table(table_name).select("car_id").execute()
            car_ids_in_database = {d['car_id'] for d in response.data}

        # Inner loop over mileage
        task_mileage = progress.add_task(
            f"[cyan]  Processing mileage {round(km_vec[0])}-{round(km_vec[-1])}...",
            total=len(km_vec[:-1]-1)
        )

        for j, km in enumerate(km_vec[:-1]):
            params['kmfrom'] = round(km_vec[j])
            params['kmto'] = round(km_vec[j+1])

            # Flag to check if the page loop completes fully
            page_limit_reached = True

            # Innermost loop over pages
            for i in range(page_limit_autoscout):
                params['page'] = i + 1
                html = requests.get(base_url, params=params).text
                soup = BeautifulSoup(html, "html.parser")
                car_listings = soup.find_all("article", class_="cldt-summary-full-item")

                if not car_listings:
                    # If no listings are found, the loop breaks early.
                    page_limit_reached = False
                    break

                for car in car_listings:
                    
                    # Check if car is already in database
                    car_id = car.get("id")
                    if car_id not in car_ids_in_upsert and ((car_id not in car_ids_in_database) or is_processing_all):

                        # Extract correct mileage
                        try:
                            data_mileage = float(car.get("data-mileage"))
                        except (ValueError, TypeError):
                            data_mileage = -1

                        # Extract correct listing price
                        try:
                            listing_price = float(car.get("data-price"))
                        except (ValueError, TypeError):
                            listing_price = -1

                        # Extract postcode
                        raw_postcode = car.get("data-listing-zip-code")
                        try:
                            postcode = raw_postcode[0:4] + raw_postcode[-2:].upper()
                            if not is_valid_format(postcode, pattern):
                                postcode = None
                        except:
                            postcode = None

                        # Extract the desired details by their data-testid attributes
                        transmission = car.find("span", {"data-testid": "VehicleDetails-transmission"})
                        fuel = car.find("span", {"data-testid": "VehicleDetails-gas_pump"})
                        power = car.find("span", {"data-testid": "VehicleDetails-speedometer"})

                        # Get the text values, stripping whitespace
                        transmission_text = transmission.get_text(strip=True) if transmission else None
                        fuel_text = fuel.get_text(strip=True) if fuel else None
                        power_text = power.get_text(strip=True) if power else None

                        kw_value = None
                        pk_value = None

                        if power_text:
                            # Extract numbers: first one before 'kW', second inside parentheses
                            match = re.search(r"(\d+)\s*kW.*\((\d+)\s*PK\)", power_text)
                            if match:
                                kw_value = float(match.group(1))
                                pk_value = float(match.group(2))

                        # Find car and model specifics
                        title_element = car.find("span", class_="ListItem_title_bold__iQJRq")
                        model_text = title_element.get_text(strip=True) if title_element else None
                        version_element = car.find("span", class_="ListItem_version__5EWfi")
                        version_text = version_element.get_text(strip=True) if version_element else None

                        # Find the actieradius span by aria-label
                        actieradius_element = car.find("span", attrs={"aria-label": "actieradius"})
                        actieradius_text = actieradius_element.get_text(strip=True) if actieradius_element else None

                        # Extract both numeric values as floats
                        ranges = [float(num) for num in
                                  re.findall(r"\d+(?:\.\d+)?", actieradius_text)] if actieradius_text else []

                        general_range = ranges[0] if len(ranges) > 0 else None
                        urban_range = ranges[1] if len(ranges) > 1 else None

                        car_info = {
                            "car_id": car_id,
                            "make": car.get("data-make"),
                            "model": car.get("data-model"),
                            "first_registration": car.get("data-first-registration"),
                            "fuel_type": car.get("data-fuel-type"),
                            "mileage": data_mileage,
                            "post_code_raw": raw_postcode,
                            "post_code": postcode,
                            "listing_price": listing_price,
                            "transmission": transmission_text,
                            "fuel_text": fuel_text,
                            "power_text": power_text,
                            "power_kw": kw_value,
                            "power_pk": pk_value,
                            "model_text": model_text,
                            "model_type": version_text,
                            "range_raw": actieradius_text,
                            "range_general": general_range,
                            "range_urban": urban_range
                        }
                        cars_to_insert.append(car_info)
                        car_ids_in_database.add(car_id)
                        car_ids_in_upsert.add(car_id)

                        # Update database in batches
                        if len(cars_to_insert) >= batch_size:
                            console.log(f"Inserting {len(cars_to_insert)} cars to the database...")
                            logging.info(f"Inserting {len(cars_to_insert)} cars to the database...")
                            supabase.table(table_name).upsert(cars_to_insert, ignore_duplicates=True).execute()
                            count_added += len(cars_to_insert)
                            cars_to_insert = []
                            car_ids_in_upsert = set()

                time.sleep(0.01)

            # Check and log if the page limit was reached for this mileage-price combination
            if page_limit_reached:
                console.log(f"Reached page limit for price: {params['pricefrom']}-{params['priceto']} and mileage: {params['kmfrom']}-{params['kmto']}")
                logging.info(f"Reached page limit for price: {params['pricefrom']}-{params['priceto']} and mileage: {params['kmfrom']}-{params['kmto']}")
                
            # Update the mileage task for each mileage range
            progress.update(task_mileage, advance=1)
        
        # Mark the mileage task as complete and remove it
        progress.remove_task(task_mileage)

        # Update the price task for each price range
        progress.update(task_price, advance=1)

    # Mark the price task as complete and remove it
    # progress.remove_task(task_price)

# --- Final Batch Insert ---
# Insert any remaining cars after all loops have finished
if cars_to_insert:
    console.log(f"Inserting final {len(cars_to_insert)} cars to the database...")
    supabase.table(table_name).upsert(cars_to_insert, ignore_duplicates=True).execute()
    count_added += len(cars_to_insert)

# console.log(f"\nTotal cars added to the database: {count_added}")
logging.info(f"\nTotal cars added to the database: {count_added}")
logging.info('Script finished successfully.')
# Out:
# Output()
# [11:03:53] Inserting 502 cars to the database...                                                  ]8;id=568256;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py\2193470145.py]8;;\:]8;id=105653;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.
file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py\2193470145.py]8;;\:]8;id=296633;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py#157\157]8;;\
# [11:31:44] Inserting 500 cars to the database...                                                  ]8;id=821700;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py\2193470145.py]8;;\:]8;id=228453;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py#157\157]8;;\
# [11:32:12] Inserting 500 cars to the database...                                                  ]8;id=965975;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py\2193470145.py]8;;\:]8;id=551188;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py#157\157]8;;\
# [11:32:33] Inserting 500 cars to the database...                                                  ]8;id=49721;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py\2193470145.py]8;;\:]8;id=269487;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py#157\157]8;;\
# [11:32:54] Inserting 500 cars to the database...                                                  ]8;id=987220;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py\2193470145.py]8;;\:]8;id=779026;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py#157\157]8;;\
# [11:33:17] Inserting 500 cars to the database...                                                  ]8;id=969100;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py\2193470145.py]8;;\:]8;id=681517;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py#157\157]8;;\
# [11:34:19] Inserting 500 cars to the database...                                                  ]8;id=592996;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py\2193470145.py]8;;\:]8;id=432000;file://C:\Users\david\AppData\Local\Temp\ipykernel_3880\2193470145.py#157\157]8;;\

# %%
cars_to_insert
# Out:
# [{'car_id': 'b83278ee-bf4e-409d-b196-a54031118d91',
#   'make': 'peugeot',
#   'model': '2008',
#   'first_registration': '01-2025',
#   'fuel_type': '2',
#   'mileage': -1,
#   'post_code_raw': '2182 DZ',
#   'post_code': None,
#   'listing_price': 429.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '108 kW (147 PK)',
#   'power_kw': 108.0,
#   'power_pk': 147.0,
#   'model_text': 'Peugeot 2008',
#   'model_type': '1.2 Hybrid 145 Style Super scherpe Private Lease a',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'b83278ee-bf4e-409d-b196-a54031118d91',
#   'make': 'peugeot',
#   'model': '2008',
#   'first_registration': '01-2025',
#   'fuel_type': '2',
#   'mileage': -1,
#   'post_code_raw': '2182 DZ',
#   'post_code': None,
#   'listing_price': 429.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '108 kW (147 PK)',
#   'power_kw': 108.0,
#   'power_pk': 147.0,
#   'model_text': 'Peugeot 2008',
#   'model_type': '1.2 Hybrid 145 Style Super scherpe Private Lease a',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '99018bd3-90dd-4364-81a4-c0d466a10982',
#   'make': 'overig',
#   'model': 'unknown',
#   'first_registration': '01-2025',
#   'fuel_type': 'unknown',
#   'mileage': 1.0,
#   'post_code_raw': '3762 EC',
#   'post_code': None,
#   'listing_price': 450.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': '- Brandstof',
#   'power_text': '1 kW (1 PK)',
#   'power_kw': 1.0,
#   'power_pk': 1.0,
#   'model_text': 'Overig',
#   'model_type': 'Mammoet Mammoet Skelter 800 Serie | Nieuwprijs 1.9',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'd1e78be8-fda0-4295-b30d-cbd5ea62b061',
#   'make': 'nissan',
#   'model': 'qashqai',
#   'first_registration': '01-2025',
#   'fuel_type': '2',
#   'mileage': -1,
#   'post_code_raw': '6004 AR',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '140 kW (190 PK)',
#   'power_kw': 140.0,
#   'power_pk': 190.0,
#   'model_text': 'Nissan Qashqai',
#   'model_type': 'e-Power 190 Tekna Plus | AUTOMAAT | PANORAMADAK |',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '491d36ff-4e79-404b-b37b-361a6032d9d3',
#   'make': 'mercedes-benz',
#   'model': 'c 200',
#   'first_registration': '05-2008',
#   'fuel_type': 'd',
#   'mileage': 290000.0,
#   'post_code_raw': '1211EA',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Diesel',
#   'power_text': '100 kW (136 PK)',
#   'power_kw': 100.0,
#   'power_pk': 136.0,
#   'model_text': 'Mercedes-Benz C 200',
#   'model_type': 'CDI DPF',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'f69b3dbe-d9b8-43a2-b87a-af6a5f0107e0',
#   'make': 'suzuki',
#   'model': 'sx4',
#   'first_registration': '04-2008',
#   'fuel_type': 'b',
#   'mileage': 74000.0,
#   'post_code_raw': '5709CM',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '79 kW (107 PK)',
#   'power_kw': 79.0,
#   'power_pk': 107.0,
#   'model_text': 'Suzuki SX4',
#   'model_type': 'SX4 1.6 Shogun',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '7fd664f3-c601-4af7-b07f-fe5d4edc7e27',
#   'make': 'bmw',
#   'model': '525',
#   'first_registration': '09-2006',
#   'fuel_type': 'd',
#   'mileage': 383600.0,
#   'post_code_raw': '6466',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Diesel',
#   'power_text': '120 kW (163 PK)',
#   'power_kw': 120.0,
#   'power_pk': 163.0,
#   'model_text': 'BMW 525',
#   'model_type': '525d Corporate M PAKKET',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'e11833cd-1eca-472d-b6aa-ae2408ea2f63',
#   'make': 'hyundai',
#   'model': 'coupe',
#   'first_registration': '07-2002',
#   'fuel_type': 'b',
#   'mileage': 158056.0,
#   'post_code_raw': '4701KL',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '123 kW (167 PK)',
#   'power_kw': 123.0,
#   'power_pk': 167.0,
#   'model_text': 'Hyundai Coupe',
#   'model_type': 'Coupe 2.7i V6 Style',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '848558a2-3863-44a2-a8ac-9be019f8ad95',
#   'make': 'mazda',
#   'model': '3',
#   'first_registration': '01-2010',
#   'fuel_type': 'b',
#   'mileage': 1900.0,
#   'post_code_raw': '1705',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '111 kW (151 PK)',
#   'power_kw': 111.0,
#   'power_pk': 151.0,
#   'model_text': 'Mazda 3',
#   'model_type': '2.0 MZR DISI TS Plus. met net nieuwe luk kopleling',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '8d6f7363-500a-4541-a40c-aae3b69281a6',
#   'make': 'fiat',
#   'model': '500',
#   'first_registration': '01-2015',
#   'fuel_type': 'b',
#   'mileage': 102000.0,
#   'post_code_raw': '7417ZR',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Fiat 500',
#   'model_type': '500 1.0 TwinAir Pop',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '1c8d1151-6a89-4f47-8c9d-3b53fcbf65a6',
#   'make': 'fiat',
#   'model': 'ducato',
#   'first_registration': '03-1988',
#   'fuel_type': 'd',
#   'mileage': 223848.0,
#   'post_code_raw': '8921BP',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Diesel',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Fiat Ducato',
#   'model_type': '280 Camper, Alkoof, 100wp zonnepaneel, 4 personen',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '83c5f616-87b3-47f7-9593-c3200563d9f6',
#   'make': 'audi',
#   'model': 'tt',
#   'first_registration': '02-2002',
#   'fuel_type': 'b',
#   'mileage': 248014.0,
#   'post_code_raw': '5491 TA',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '132 kW (179 PK)',
#   'power_kw': 132.0,
#   'power_pk': 179.0,
#   'model_text': 'Audi TT',
#   'model_type': '1.8 T COUPE  180PK',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'f2e869c6-e5d2-4ae7-b5e0-f9e229221be9',
#   'make': 'audi',
#   'model': 'a4',
#   'first_registration': '01-2011',
#   'fuel_type': 'b',
#   'mileage': 247285.0,
#   'post_code_raw': '1081HK',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '118 kW (160 PK)',
#   'power_kw': 118.0,
#   'power_pk': 160.0,
#   'model_text': 'Audi A4',
#   'model_type': 'A4 1.8 TFSI',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '657bbb85-da4a-490e-8ad7-4c66bbbd0f8f',
#   'make': 'renault',
#   'model': 'megane',
#   'first_registration': '07-2014',
#   'fuel_type': 'b',
#   'mileage': 184000.0,
#   'post_code_raw': '2407 BK',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '85 kW (116 PK)',
#   'power_kw': 85.0,
#   'power_pk': 116.0,
#   'model_text': 'Renault Megane',
#   'model_type': 'Grandtour ENERGY TCe 115 Start & Stopp Paris',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '1f751005-2c17-44a1-acbb-918f243397b5',
#   'make': 'renault',
#   'model': 'megane',
#   'first_registration': '11-2012',
#   'fuel_type': 'b',
#   'mileage': 225000.0,
#   'post_code_raw': '7512ZJ',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '85 kW (116 PK)',
#   'power_kw': 85.0,
#   'power_pk': 116.0,
#   'model_text': 'Renault Megane',
#   'model_type': '1.2 TCe GT-Line',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '112cc42f-974a-4e61-926d-32a2c2d059e8',
#   'make': 'volkswagen',
#   'model': 'polo',
#   'first_registration': '08-2010',
#   'fuel_type': 'b',
#   'mileage': 193000.0,
#   'post_code_raw': '3437bw',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '51 kW (69 PK)',
#   'power_kw': 51.0,
#   'power_pk': 69.0,
#   'model_text': 'Volkswagen Polo',
#   'model_type': 'Polo 1.2-12V Trendline',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '0ae9ee3e-2064-467f-a3ea-785954f2fc53',
#   'make': 'citroen',
#   'model': 'c4 picasso',
#   'first_registration': '09-2011',
#   'fuel_type': 'b',
#   'mileage': 164337.0,
#   'post_code_raw': '9502 EZ',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '88 kW (120 PK)',
#   'power_kw': 88.0,
#   'power_pk': 120.0,
#   'model_text': 'Citroen C4 Picasso',
#   'model_type': '1.6 VTi Attraction 7 persoons NAVI-AIRCO-TREKHAAK',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '16612c25-e20a-480f-a302-5d5fb4bd32e0',
#   'make': 'renault',
#   'model': 'clio',
#   'first_registration': '07-1992',
#   'fuel_type': 'b',
#   'mileage': 63000.0,
#   'post_code_raw': '1015KV',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '99 kW (135 PK)',
#   'power_kw': 99.0,
#   'power_pk': 135.0,
#   'model_text': 'Renault Clio',
#   'model_type': '1.8 16V',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '147f55e0-535f-4de3-8f7b-5b0d6ed9f9ea',
#   'make': 'mercedes-benz',
#   'model': 'b 160',
#   'first_registration': '03-2011',
#   'fuel_type': 'b',
#   'mileage': 225435.0,
#   'post_code_raw': '1069BS',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '70 kW (95 PK)',
#   'power_kw': 70.0,
#   'power_pk': 95.0,
#   'model_text': 'Mercedes-Benz B 160',
#   'model_type': 'B 160 BlueE.',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'e14c6f92-560c-47c7-ad9e-03c845acaad3',
#   'make': 'peugeot',
#   'model': '108',
#   'first_registration': '10-2015',
#   'fuel_type': 'b',
#   'mileage': 129394.0,
#   'post_code_raw': '4761gj',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '51 kW (69 PK)',
#   'power_kw': 51.0,
#   'power_pk': 69.0,
#   'model_text': 'Peugeot 108',
#   'model_type': '108 1.0 e-VTi Blue Lease',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'bb3d810a-aca0-4b99-94d0-503f1215cb8c',
#   'make': 'mercedes-benz',
#   'model': 'c 180',
#   'first_registration': '05-2009',
#   'fuel_type': 'b',
#   'mileage': 286000.0,
#   'post_code_raw': '4902ZD',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '115 kW (156 PK)',
#   'power_kw': 115.0,
#   'power_pk': 156.0,
#   'model_text': 'Mercedes-Benz C 180',
#   'model_type': 'K BlueE. Bns Cl.',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '9f04f51d-fad0-4083-9627-0ed3b529c391',
#   'make': 'bmw',
#   'model': 'x5',
#   'first_registration': '06-2004',
#   'fuel_type': 'b',
#   'mileage': 355000.0,
#   'post_code_raw': '3026AC',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '235 kW (320 PK)',
#   'power_kw': 235.0,
#   'power_pk': 320.0,
#   'model_text': 'BMW X5',
#   'model_type': '4.4 i',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'def2d589-364c-4347-aa17-15f9a5a4ae0f',
#   'make': 'fiat',
#   'model': '500',
#   'first_registration': '01-2009',
#   'fuel_type': 'b',
#   'mileage': 102040.0,
#   'post_code_raw': '1441 CG',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '73 kW (99 PK)',
#   'power_kw': 73.0,
#   'power_pk': 99.0,
#   'model_text': 'Fiat 500',
#   'model_type': '1.4 16V Sport',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '0e253cc9-e1aa-4fac-ac2c-3988a06b18c6',
#   'make': 'peugeot',
#   'model': '208',
#   'first_registration': '01-2025',
#   'fuel_type': '2',
#   'mileage': 5.0,
#   'post_code_raw': '2182 DZ',
#   'post_code': None,
#   'listing_price': 369.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '81 kW (110 PK)',
#   'power_kw': 81.0,
#   'power_pk': 110.0,
#   'model_text': 'Peugeot 208',
#   'model_type': 'Style Deze prijs is uitsluitend een vanaf prijs vo',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'bca650b7-8d64-4c7d-9659-63dcc9f5f255',
#   'make': 'peugeot',
#   'model': '208',
#   'first_registration': '01-2025',
#   'fuel_type': '2',
#   'mileage': 5.0,
#   'post_code_raw': '2182 DZ',
#   'post_code': None,
#   'listing_price': 369.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '81 kW (110 PK)',
#   'power_kw': 81.0,
#   'power_pk': 110.0,
#   'model_text': 'Peugeot 208',
#   'model_type': 'Style Deze prijs is uitsluitend een vanaf prijs vo',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'e98886dc-af94-4e55-982a-48027e5b1177',
#   'make': 'toyota',
#   'model': 'aygo x',
#   'first_registration': '01-2025',
#   'fuel_type': 'b',
#   'mileage': 3.0,
#   'post_code_raw': '4202 MS',
#   'post_code': None,
#   'listing_price': 269.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '53 kW (72 PK)',
#   'power_kw': 53.0,
#   'power_pk': 72.0,
#   'model_text': 'Toyota Aygo X',
#   'model_type': '1.0 VVT-i MT Play | Private leaseactie! Meerprijs',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'ad3d40e4-76f7-4485-ae98-6aaf3cc9904f',
#   'make': 'kia',
#   'model': 'stonic',
#   'first_registration': '08-2025',
#   'fuel_type': 'b',
#   'mileage': 10.0,
#   'post_code_raw': '3712 DE',
#   'post_code': None,
#   'listing_price': 349.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '74 kW (101 PK)',
#   'power_kw': 74.0,
#   'power_pk': 101.0,
#   'model_text': 'Kia Stonic',
#   'model_type': '1.0 T-GDi DynamicLine ZOMERWEKEN  ANWB Private lea',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'a3f5a719-336a-444d-9989-1ef3acfe256f',
#   'make': 'kia',
#   'model': 'picanto',
#   'first_registration': '01-2025',
#   'fuel_type': 'b',
#   'mileage': 10.0,
#   'post_code_raw': '3712 DE',
#   'post_code': None,
#   'listing_price': 259.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '46 kW (63 PK)',
#   'power_kw': 46.0,
#   'power_pk': 63.0,
#   'model_text': 'Kia Picanto',
#   'model_type': '1.0 DPI DynamicLine ZOMERWEKEN ANWB Private lease',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'a1a5130b-5285-4592-96b8-4c6ddc0550e7',
#   'make': 'kia',
#   'model': 'ev3',
#   'first_registration': '01-2025',
#   'fuel_type': 'e',
#   'mileage': 10.0,
#   'post_code_raw': '1411 AW',
#   'post_code': None,
#   'listing_price': 479.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektrisch',
#   'power_text': '150 kW (204 PK)',
#   'power_kw': 150.0,
#   'power_pk': 204.0,
#   'model_text': 'Kia EV3',
#   'model_type': 'Air 58.3 kWh ANWB Private lease nu Vanaf €. 479,=',
#   'range_raw': '436 km actieradius',
#   'range_general': 436.0,
#   'range_urban': None},
#  {'car_id': '6fa548c7-075c-464d-8ce5-a8a3d7eb761c',
#   'make': 'kia',
#   'model': 'stonic',
#   'first_registration': '05-2025',
#   'fuel_type': 'b',
#   'mileage': 10.0,
#   'post_code_raw': '1411 AW',
#   'post_code': None,
#   'listing_price': 394.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '74 kW (101 PK)',
#   'power_kw': 74.0,
#   'power_pk': 101.0,
#   'model_text': 'Kia Stonic',
#   'model_type': '1.0 T-GDi MHEV ComfortLine Private lease nu Vanaf',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '9a643038-b5f5-4b0d-a955-6445b1ee26a8',
#   'make': 'kia',
#   'model': 'niro',
#   'first_registration': '01-2025',
#   'fuel_type': '2',
#   'mileage': 10.0,
#   'post_code_raw': '1411 AW',
#   'post_code': None,
#   'listing_price': 449.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '95 kW (129 PK)',
#   'power_kw': 95.0,
#   'power_pk': 129.0,
#   'model_text': 'Kia Niro',
#   'model_type': '1.6 GDi Hybrid DynamicLine ANWB Private lease nu V',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '77db4d7b-ce43-4d75-8121-ed80b0358d02',
#   'make': 'kia',
#   'model': "ceed / cee'd",
#   'first_registration': '01-2025',
#   'fuel_type': 'b',
#   'mileage': 10.0,
#   'post_code_raw': '1411 AW',
#   'post_code': None,
#   'listing_price': 399.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '74 kW (101 PK)',
#   'power_kw': 74.0,
#   'power_pk': 101.0,
#   'model_text': "Kia Ceed / cee'd",
#   'model_type': '1.0 T-GDi ComfortLine ANWB Private lease nu Vanaf',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'ed344e8b-ba3c-44b9-8648-d11febadf7bf',
#   'make': 'kia',
#   'model': 'picanto',
#   'first_registration': '01-2025',
#   'fuel_type': 'b',
#   'mileage': 10.0,
#   'post_code_raw': '1411 AW',
#   'post_code': None,
#   'listing_price': 274.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '46 kW (63 PK)',
#   'power_kw': 46.0,
#   'power_pk': 63.0,
#   'model_text': 'Kia Picanto',
#   'model_type': '1.0 DPI DynamicLine ANWB Private lease nu Vanaf €.',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '8d45742a-f439-4756-8fad-eb8004d6538f',
#   'make': 'peugeot',
#   'model': '2008',
#   'first_registration': '01-2025',
#   'fuel_type': 'b',
#   'mileage': 15.0,
#   'post_code_raw': '2182 DZ',
#   'post_code': None,
#   'listing_price': 429.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '75 kW (102 PK)',
#   'power_kw': 75.0,
#   'power_pk': 102.0,
#   'model_text': 'Peugeot 2008',
#   'model_type': '1.2 PureTech 100 Style Super scherp Private Lease',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'b6fb291f-4ebb-4f97-81b4-cc0d655888f2',
#   'make': 'ford',
#   'model': 'e-transit',
#   'first_registration': '06-2025',
#   'fuel_type': 'e',
#   'mileage': 50.0,
#   'post_code_raw': '5406 XN',
#   'post_code': None,
#   'listing_price': 12.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektrisch',
#   'power_text': '135 kW (184 PK)',
#   'power_kw': 135.0,
#   'power_pk': 184.0,
#   'model_text': 'Ford E-Transit',
#   'model_type': 'Post.nl Uitvoering (informeer naar de mogelijkhede',
#   'range_raw': '248 km actieradius | 378 km (stedelijk)',
#   'range_general': 248.0,
#   'range_urban': 378.0},
#  {'car_id': 'c9883795-fc13-4378-8adf-3ed101a61164',
#   'make': 'overig',
#   'model': 'unknown',
#   'first_registration': '03-2024',
#   'fuel_type': 'e',
#   'mileage': 31.0,
#   'post_code_raw': '7554 TA',
#   'post_code': None,
#   'listing_price': 199.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektrisch',
#   'power_text': '4 kW (5 PK)',
#   'power_kw': 4.0,
#   'power_pk': 5.0,
#   'model_text': 'Overig',
#   'model_type': 'Eli Zero Electric',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'ec81eba4-596f-4c96-8c9f-ef7b56bf200f',
#   'make': 'autobianchi',
#   'model': 'unknown',
#   'first_registration': '02-1967',
#   'fuel_type': 'b',
#   'mileage': 71.0,
#   'post_code_raw': '1422 AE',
#   'post_code': None,
#   'listing_price': 5000.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '- kW (- PK)',
#   'power_kw': None,
#   'power_pk': None,
#   'model_text': 'Autobianchi',
#   'model_type': 'PANORAMICA   - ONLINE AUCTION',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '9b9e8f5c-daa9-43e5-8529-e3ec84f43779',
#   'make': 'opel',
#   'model': 'astra',
#   'first_registration': '07-2007',
#   'fuel_type': 'b',
#   'mileage': 266.0,
#   'post_code_raw': '1062',
#   'post_code': None,
#   'listing_price': 440.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '85 kW (116 PK)',
#   'power_kw': 85.0,
#   'power_pk': 116.0,
#   'model_text': 'Opel Astra',
#   'model_type': '1.4 16V Coupe',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '5ae83e8b-d407-45fd-a4f4-1f2d40231ce7',
#   'make': 'daf',
#   'model': 'unknown',
#   'first_registration': '05-1976',
#   'fuel_type': 'b',
#   'mileage': 27075.0,
#   'post_code_raw': '9521AT',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '29 kW (39 PK)',
#   'power_kw': 29.0,
#   'power_pk': 39.0,
#   'model_text': 'DAF',
#   'model_type': '4623',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '6a536d20-88a0-4aff-a08f-bf7684fd97c2',
#   'make': 'mercedes-benz',
#   'model': 'glb 200',
#   'first_registration': '06-2022',
#   'fuel_type': 'b',
#   'mileage': 27741.0,
#   'post_code_raw': '9231 HT',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '120 kW (163 PK)',
#   'power_kw': 120.0,
#   'power_pk': 163.0,
#   'model_text': 'Mercedes-Benz GLB 200',
#   'model_type': 'Business Line',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '5c303a0a-5245-4c57-bdf5-30f4f467ac0a',
#   'make': 'peugeot',
#   'model': 'expert',
#   'first_registration': '10-2022',
#   'fuel_type': 'd',
#   'mileage': 34445.0,
#   'post_code_raw': '5481 SG',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Diesel',
#   'power_text': '75 kW (102 PK)',
#   'power_kw': 75.0,
#   'power_pk': 102.0,
#   'model_text': 'Peugeot Expert',
#   'model_type': '1.5 BlueHDI 100 Standard Premium Airco | Audio | L',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '84fae571-b4b7-4ccd-91a1-d41672bb0f65',
#   'make': 'mercedes-benz',
#   'model': 'a 200',
#   'first_registration': '09-2019',
#   'fuel_type': 'b',
#   'mileage': 38578.0,
#   'post_code_raw': '1704 RB',
#   'post_code': None,
#   'listing_price': 11.0,
#   'transmission': '- Transmissie',
#   'fuel_text': 'Benzine',
#   'power_text': '120 kW (163 PK)',
#   'power_kw': 120.0,
#   'power_pk': 163.0,
#   'model_text': 'Mercedes-Benz A 200',
#   'model_type': 'Business Solution AMG Upgrade',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'd896c226-146a-45cc-b494-85b30c21b9b6',
#   'make': 'toyota',
#   'model': 'verso-s',
#   'first_registration': '01-2012',
#   'fuel_type': 'b',
#   'mileage': 48262.0,
#   'post_code_raw': '1704 RB',
#   'post_code': None,
#   'listing_price': 11.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '73 kW (99 PK)',
#   'power_kw': 73.0,
#   'power_pk': 99.0,
#   'model_text': 'Toyota Verso-S',
#   'model_type': '1.3 VVT-i Aspiration | NAVI | PANO | Camera | Auto',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'b3c4de4f-40a5-4ecf-938e-8ad3c15f8b00',
#   'make': 'ford',
#   'model': 'focus',
#   'first_registration': '09-2022',
#   'fuel_type': '2',
#   'mileage': 50860.0,
#   'post_code_raw': '4462 GP',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '91 kW (124 PK)',
#   'power_kw': 91.0,
#   'power_pk': 124.0,
#   'model_text': 'Ford Focus',
#   'model_type': '1.0 EcoBoost Hybrid 125pk Titanium',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'c888d1ad-fad5-4737-b7a7-5f027eaca239',
#   'make': 'aixam',
#   'model': 'unknown',
#   'first_registration': '08-2005',
#   'fuel_type': 'd',
#   'mileage': 59820.0,
#   'post_code_raw': '3084 CB',
#   'post_code': None,
#   'listing_price': 490.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Diesel',
#   'power_text': '4 kW (5 PK)',
#   'power_kw': 4.0,
#   'power_pk': 5.0,
#   'model_text': 'Aixam',
#   'model_type': 'AIXAM 300',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '4dbc1186-8198-4703-8880-02483717c39c',
#   'make': 'audi',
#   'model': 'a3',
#   'first_registration': '08-2020',
#   'fuel_type': 'b',
#   'mileage': 68126.0,
#   'post_code_raw': '5311 GH',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '110 kW (150 PK)',
#   'power_kw': 110.0,
#   'power_pk': 150.0,
#   'model_text': 'Audi A3',
#   'model_type': 'Sportback 35 TFSI Business edition Virtueel| B&O|',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'e23461bd-a56e-43b1-ba96-b4c589b1920b',
#   'make': 'volkswagen',
#   'model': 'polo',
#   'first_registration': '02-2022',
#   'fuel_type': 'b',
#   'mileage': 63538.0,
#   'post_code_raw': '8304 AP',
#   'post_code': None,
#   'listing_price': 19.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '70 kW (95 PK)',
#   'power_kw': 70.0,
#   'power_pk': 95.0,
#   'model_text': 'Volkswagen Polo',
#   'model_type': '1.0 TSI Style 95PK Adaptieve Cruise Controle, Acht',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '0d8ac505-abc8-43df-8e6e-c925d3c6cc0e',
#   'make': 'kia',
#   'model': 'rio',
#   'first_registration': '01-2004',
#   'fuel_type': 'b',
#   'mileage': 77000.0,
#   'post_code_raw': '4201GL',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '60 kW (82 PK)',
#   'power_kw': 60.0,
#   'power_pk': 82.0,
#   'model_text': 'Kia Rio',
#   'model_type': '1.3 RS Visto',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'c0af5350-f983-4ece-a577-9ab38f290d5a',
#   'make': 'bmw',
#   'model': '530',
#   'first_registration': '05-2021',
#   'fuel_type': '2',
#   'mileage': 78147.0,
#   'post_code_raw': '2685 AP',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '135 kW (184 PK)',
#   'power_kw': 135.0,
#   'power_pk': 184.0,
#   'model_text': 'BMW 530',
#   'model_type': '5-serie Touring 530e High Executive | Pano | M Spo',
#   'range_raw': '50 km actieradius',
#   'range_general': 50.0,
#   'range_urban': None},
#  {'car_id': '190283cc-e87e-4ff6-9930-e31a48edb129',
#   'make': 'rover',
#   'model': '111',
#   'first_registration': '04-1997',
#   'fuel_type': 'b',
#   'mileage': 83000.0,
#   'post_code_raw': '6827BJ',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Rover 111',
#   'model_type': '111 Kensington',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '1917cf14-5407-4bb8-9133-73e73c505641',
#   'make': 'volkswagen',
#   'model': 'up!',
#   'first_registration': '05-2020',
#   'fuel_type': 'b',
#   'mileage': 86832.0,
#   'post_code_raw': '7211 BA',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Volkswagen up!',
#   'model_type': '1.0 60PK 4D BMT Move up! | Origineel NL |',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '8ad14126-b7e5-477b-9fc3-1db4c89e6fd6',
#   'make': 'audi',
#   'model': 'a3',
#   'first_registration': '09-2017',
#   'fuel_type': '2',
#   'mileage': 90000.0,
#   'post_code_raw': '2661 JK',
#   'post_code': None,
#   'listing_price': 349.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektro/Benzine',
#   'power_text': '- kW (- PK)',
#   'power_kw': None,
#   'power_pk': None,
#   'model_text': 'Audi A3',
#   'model_type': 'Sportback div winterwielen sets v/a € 350.-',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'ccc46588-1c8c-4a0f-a996-b13ad9c46e30',
#   'make': 'mini',
#   'model': 'one',
#   'first_registration': '12-2010',
#   'fuel_type': 'b',
#   'mileage': 90177.0,
#   'post_code_raw': '1704 RB',
#   'post_code': None,
#   'listing_price': 11.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '72 kW (98 PK)',
#   'power_kw': 72.0,
#   'power_pk': 98.0,
#   'model_text': 'MINI One',
#   'model_type': 'Mini 1.6 MINIMALIST Business Line | Navi | CRUISEC',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'f6167307-d310-4978-b81d-61c376b3f1dd',
#   'make': 'peugeot',
#   'model': '207',
#   'first_registration': '01-2007',
#   'fuel_type': 'b',
#   'mileage': 93200.0,
#   'post_code_raw': '1114AK',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '65 kW (88 PK)',
#   'power_kw': 65.0,
#   'power_pk': 88.0,
#   'model_text': 'Peugeot 207',
#   'model_type': '207 1.4-16V XS Pack',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '3910b6a4-1ee5-4d07-8445-3c25332d5207',
#   'make': 'fiat',
#   'model': '500',
#   'first_registration': '05-2011',
#   'fuel_type': 'b',
#   'mileage': 92033.0,
#   'post_code_raw': '2676 LV',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '51 kW (69 PK)',
#   'power_kw': 51.0,
#   'power_pk': 69.0,
#   'model_text': 'Fiat 500',
#   'model_type': '1.2 Lounge/nardo-grey/airco/PANO/LM-velgen/2 sleut',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'fcac1fad-5ab0-4810-9614-82857438ea34',
#   'make': 'suzuki',
#   'model': 'swift',
#   'first_registration': '07-2001',
#   'fuel_type': 'b',
#   'mileage': 94888.0,
#   'post_code_raw': '6211PM',
#   'post_code': None,
#   'listing_price': 200.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '63 kW (86 PK)',
#   'power_kw': 63.0,
#   'power_pk': 86.0,
#   'model_text': 'Suzuki Swift',
#   'model_type': 'Swift 1.3-16V Summum',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '66b8cace-1370-4abd-9f23-66596d5af0d6',
#   'make': 'daihatsu',
#   'model': 'cuore',
#   'first_registration': '06-1999',
#   'fuel_type': 'b',
#   'mileage': 100000.0,
#   'post_code_raw': '6011re',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '41 kW (56 PK)',
#   'power_kw': 41.0,
#   'power_pk': 56.0,
#   'model_text': 'Daihatsu Cuore',
#   'model_type': 'GL',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '0ed7286f-e769-4015-a04d-1ada38cd68a9',
#   'make': 'ford',
#   'model': 'ka/ka+',
#   'first_registration': '01-2006',
#   'fuel_type': 'b',
#   'mileage': 100000.0,
#   'post_code_raw': '1566Gh',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Ford Ka/Ka+',
#   'model_type': 'Ka First Edition',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '60c2505d-f772-434b-966b-f5beb82187e0',
#   'make': 'pontiac',
#   'model': '6000',
#   'first_registration': '07-1988',
#   'fuel_type': 'b',
#   'mileage': 99999.0,
#   'post_code_raw': '1422 AE',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '- kW (- PK)',
#   'power_kw': None,
#   'power_pk': None,
#   'model_text': 'Pontiac 6000',
#   'model_type': 'LE  - ONLINE AUCTION',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '14878f14-c3c8-4c7c-994a-c931171c8963',
#   'make': 'daihatsu',
#   'model': 'cuore',
#   'first_registration': '07-1996',
#   'fuel_type': 'b',
#   'mileage': 99000.0,
#   'post_code_raw': '8935',
#   'post_code': None,
#   'listing_price': 250.0,
#   'transmission': '- Transmissie',
#   'fuel_text': 'Benzine',
#   'power_text': '32 kW (44 PK)',
#   'power_kw': 32.0,
#   'power_pk': 44.0,
#   'model_text': 'Daihatsu Cuore',
#   'model_type': '850 Magic',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '7d72d869-ad9a-4369-99fe-ac3ee4fb9a18',
#   'make': 'fiat',
#   'model': 'seicento',
#   'first_registration': '06-2003',
#   'fuel_type': 'b',
#   'mileage': 96500.0,
#   'post_code_raw': '7531CG',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '40 kW (54 PK)',
#   'power_kw': 40.0,
#   'power_pk': 54.0,
#   'model_text': 'Fiat Seicento',
#   'model_type': '1.1 S',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '8afbfa50-f15f-4caf-981e-fd0c8f9f28dc',
#   'make': 'ford',
#   'model': 'fiesta',
#   'first_registration': '11-2018',
#   'fuel_type': 'b',
#   'mileage': 96346.0,
#   'post_code_raw': '5473 KW',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '73 kW (99 PK)',
#   'power_kw': 73.0,
#   'power_pk': 99.0,
#   'model_text': 'Ford Fiesta',
#   'model_type': '1.0 * AUTOMAAT * 5 DRS * AIRCO * NAVI *',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'e40e55fd-0c97-458c-8a93-0fa2038b1891',
#   'make': 'mazda',
#   'model': 'cx-3',
#   'first_registration': '02-2020',
#   'fuel_type': 'b',
#   'mileage': 94170.0,
#   'post_code_raw': '5473 KW',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '89 kW (121 PK)',
#   'power_kw': 89.0,
#   'power_pk': 121.0,
#   'model_text': 'Mazda CX-3',
#   'model_type': '2.0 SkyActiv-G 120 TS * NAVIGATIE * TREKHAAK',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '522d69b1-f0e5-43d6-ba14-dfee9bb9c3a5',
#   'make': 'bmw',
#   'model': 'x1',
#   'first_registration': '06-2013',
#   'fuel_type': 'b',
#   'mileage': 94083.0,
#   'post_code_raw': '5473 KW',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '110 kW (150 PK)',
#   'power_kw': 110.0,
#   'power_pk': 150.0,
#   'model_text': 'BMW X1',
#   'model_type': 'sDrive18i * AUTOMAAT * NAVIGATIE * AIRCO *',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '8ff74bcf-7e8c-4772-8521-36e8c6612ce8',
#   'make': 'renault',
#   'model': 'twingo',
#   'first_registration': '09-2003',
#   'fuel_type': 'b',
#   'mileage': 109039.0,
#   'post_code_raw': '4004 JM',
#   'post_code': None,
#   'listing_price': 395.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Renault Twingo',
#   'model_type': '1.2 16V 2005 E4 HANDGESCHAKELD - 29-NG-LB',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'f95b5f05-03bf-4d05-a4c9-5fffc083230d',
#   'make': 'volkswagen',
#   'model': 'golf',
#   'first_registration': '04-2000',
#   'fuel_type': 'b',
#   'mileage': 102000.0,
#   'post_code_raw': '1396kt',
#   'post_code': None,
#   'listing_price': 300.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Volkswagen Golf',
#   'model_type': '1.4-16V Trendline',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'd37e5a36-629a-4bc8-bc54-c76553e14d36',
#   'make': 'peugeot',
#   'model': '308',
#   'first_registration': '08-2019',
#   'fuel_type': 'b',
#   'mileage': 107783.0,
#   'post_code_raw': '7903 AG',
#   'post_code': None,
#   'listing_price': 50.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '96 kW (131 PK)',
#   'power_kw': 96.0,
#   'power_pk': 131.0,
#   'model_text': 'Peugeot 308',
#   'model_type': '1.2 PureTech Blue Lease Premium AUTOMAAT, Clima, P',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'cf7e6e78-b52f-4845-b417-0a2a5e0a8949',
#   'make': 'peugeot',
#   'model': '307',
#   'first_registration': '02-2002',
#   'fuel_type': 'b',
#   'mileage': 109927.0,
#   'post_code_raw': '1704 RB',
#   'post_code': None,
#   'listing_price': 11.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '80 kW (109 PK)',
#   'power_kw': 80.0,
#   'power_pk': 109.0,
#   'model_text': 'Peugeot 307',
#   'model_type': '1.6-16V XS | Airco | Electr. ramen | APK | NAP',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'a0a72278-c0f1-4951-986c-c9af81a7f3c2',
#   'make': 'opel',
#   'model': 'agila',
#   'first_registration': '05-2002',
#   'fuel_type': 'b',
#   'mileage': 120000.0,
#   'post_code_raw': '7241nb',
#   'post_code': None,
#   'listing_price': 400.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Opel Agila',
#   'model_type': '1.2-16V Njoy',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'cf09be1c-e3a0-4495-9a84-62a619231e27',
#   'make': 'peugeot',
#   'model': '108',
#   'first_registration': '12-2016',
#   'fuel_type': 'b',
#   'mileage': 116301.0,
#   'post_code_raw': '5481 SG',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '50 kW (68 PK)',
#   'power_kw': 50.0,
#   'power_pk': 68.0,
#   'model_text': 'Peugeot 108',
#   'model_type': '1.0 e-VTi Active',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '7a2830d3-6e87-45f1-ab7e-14a8eb761d5e',
#   'make': 'lancia',
#   'model': 'ypsilon',
#   'first_registration': '05-1999',
#   'fuel_type': 'b',
#   'mileage': 112961.0,
#   'post_code_raw': '6136 KT',
#   'post_code': None,
#   'listing_price': 300.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Lancia Ypsilon',
#   'model_type': '1.2 LS',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'a707e677-fd12-467b-bdea-b5d87a8dd9e1',
#   'make': 'chevrolet',
#   'model': 'matiz',
#   'first_registration': '08-2008',
#   'fuel_type': 'b',
#   'mileage': 110798.0,
#   'post_code_raw': '9462RH',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '49 kW (67 PK)',
#   'power_kw': 49.0,
#   'power_pk': 67.0,
#   'model_text': 'Chevrolet Matiz',
#   'model_type': '1.0',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '1dd2a156-079e-4ae2-aa54-305dc9010fee',
#   'make': 'suzuki',
#   'model': 'alto',
#   'first_registration': '08-2002',
#   'fuel_type': 'b',
#   'mileage': 120000.0,
#   'post_code_raw': '2421XN',
#   'post_code': None,
#   'listing_price': 400.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Benzine',
#   'power_text': '46 kW (63 PK)',
#   'power_kw': 46.0,
#   'power_pk': 63.0,
#   'model_text': 'Suzuki Alto',
#   'model_type': '1.1 GLS',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'ab4c91f5-f4e8-4c8f-85e8-cda9c0287beb',
#   'make': 'renault',
#   'model': 'twingo',
#   'first_registration': '12-2015',
#   'fuel_type': 'b',
#   'mileage': 117505.0,
#   'post_code_raw': '1704 RB',
#   'post_code': None,
#   'listing_price': 11.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '52 kW (71 PK)',
#   'power_kw': 52.0,
#   'power_pk': 71.0,
#   'model_text': 'Renault Twingo',
#   'model_type': '1.0 SCe Collection | CRUISECR | Airco | NAP | APK',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'a76e6afc-6ac8-4282-a526-af3ac1f3314c',
#   'make': 'daihatsu',
#   'model': 'cuore',
#   'first_registration': '10-1998',
#   'fuel_type': 'b',
#   'mileage': 116539.0,
#   'post_code_raw': '7541AT',
#   'post_code': None,
#   'listing_price': 400.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '43 kW (58 PK)',
#   'power_kw': 43.0,
#   'power_pk': 58.0,
#   'model_text': 'Daihatsu Cuore',
#   'model_type': 'Cuore 850 Trendy',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '5b732218-b52a-458c-b2f1-d3da1d5941b6',
#   'make': 'opel',
#   'model': 'ampera-e',
#   'first_registration': '01-2018',
#   'fuel_type': 'e',
#   'mileage': 111482.0,
#   'post_code_raw': '4538 AR',
#   'post_code': None,
#   'listing_price': 1.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Elektrisch',
#   'power_text': '- kW (- PK)',
#   'power_kw': None,
#   'power_pk': None,
#   'model_text': 'Opel Ampera-E',
#   'model_type': 'Executive 60 kWh',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '1166de6a-a589-4b04-8514-244431afb942',
#   'make': 'daewoo',
#   'model': 'matiz',
#   'first_registration': '11-2004',
#   'fuel_type': 'b',
#   'mileage': 128180.0,
#   'post_code_raw': '1704 RT',
#   'post_code': None,
#   'listing_price': 499.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '47 kW (64 PK)',
#   'power_kw': 47.0,
#   'power_pk': 64.0,
#   'model_text': 'Daewoo Matiz',
#   'model_type': '1.0 Class',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'f6593532-3b34-414b-9483-27ecdaded744',
#   'make': 'renault',
#   'model': 'r 5',
#   'first_registration': '03-1991',
#   'fuel_type': 'b',
#   'mileage': 125000.0,
#   'post_code_raw': '6687lc',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '35 kW (48 PK)',
#   'power_kw': 35.0,
#   'power_pk': 48.0,
#   'model_text': 'Renault R 5',
#   'model_type': '1.1 sl',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '3d99a270-47a7-4b89-b4af-457c35dfc06e',
#   'make': 'ford',
#   'model': 'fiesta',
#   'first_registration': '09-2000',
#   'fuel_type': 'b',
#   'mileage': 124345.0,
#   'post_code_raw': '3331xm',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Ford Fiesta',
#   'model_type': 'Fiesta 1.3-16V Century',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '425d5fbb-a3e8-47e5-8186-bb99e34ed098',
#   'make': 'opel',
#   'model': 'agila',
#   'first_registration': '06-2000',
#   'fuel_type': 'b',
#   'mileage': 128000.0,
#   'post_code_raw': '3204VH',
#   'post_code': None,
#   'listing_price': 450.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Opel Agila',
#   'model_type': '1.2-16V Comfort',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '0752a454-466a-48d7-af9c-4fc12010734f',
#   'make': 'peugeot',
#   'model': '206',
#   'first_registration': '02-2005',
#   'fuel_type': 'b',
#   'mileage': 122204.0,
#   'post_code_raw': '6372KX',
#   'post_code': None,
#   'listing_price': 450.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Peugeot 206',
#   'model_type': '206 1.4 X-line',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '5ebe6095-59a3-4b50-bedb-991ecf78186b',
#   'make': 'ford',
#   'model': 'ka/ka+',
#   'first_registration': '01-2002',
#   'fuel_type': 'b',
#   'mileage': 121629.0,
#   'post_code_raw': '1435CG',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Ford Ka/Ka+',
#   'model_type': 'Ka/Ka+ 1.3 Trend',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '00c3ee63-9e50-4cd1-9334-16264a6ffd7a',
#   'make': 'opel',
#   'model': 'meriva',
#   'first_registration': '08-2003',
#   'fuel_type': 'b',
#   'mileage': 123221.0,
#   'post_code_raw': '6245lj',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '64 kW (87 PK)',
#   'power_kw': 64.0,
#   'power_pk': 87.0,
#   'model_text': 'Opel Meriva',
#   'model_type': '1.6 Essentia',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '2c296da5-2aaa-4530-acb7-a54b7e4b225a',
#   'make': 'fiat',
#   'model': 'seicento',
#   'first_registration': '08-2001',
#   'fuel_type': 'b',
#   'mileage': 129000.0,
#   'post_code_raw': '8621 CA',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '40 kW (54 PK)',
#   'power_kw': 40.0,
#   'power_pk': 54.0,
#   'model_text': 'Fiat Seicento',
#   'model_type': '1.1 S',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '05d7aabd-d91d-4bd3-a547-75211e29e45e',
#   'make': 'renault',
#   'model': 'clio',
#   'first_registration': '03-2013',
#   'fuel_type': 'b',
#   'mileage': 126746.0,
#   'post_code_raw': '1704 RB',
#   'post_code': None,
#   'listing_price': 11.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '66 kW (90 PK)',
#   'power_kw': 66.0,
#   'power_pk': 90.0,
#   'model_text': 'Renault Clio',
#   'model_type': '0.9 TCe Dynamique | Navi | CRUISECR | Keyless | PD',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'ad557ccc-eb40-4783-8857-748efc3370fb',
#   'make': 'ford',
#   'model': 'ka/ka+',
#   'first_registration': '08-2005',
#   'fuel_type': 'b',
#   'mileage': 123174.0,
#   'post_code_raw': '5991 NG',
#   'post_code': None,
#   'listing_price': 400.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '51 kW (69 PK)',
#   'power_kw': 51.0,
#   'power_pk': 69.0,
#   'model_text': 'Ford Ka/Ka+',
#   'model_type': '1.3 Trend',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '00dfe432-2d65-46b9-b425-421b3bbee15c',
#   'make': 'chevrolet',
#   'model': 'matiz',
#   'first_registration': '06-2005',
#   'fuel_type': 'b',
#   'mileage': 128000.0,
#   'post_code_raw': '5704',
#   'post_code': None,
#   'listing_price': 399.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '38 kW (52 PK)',
#   'power_kw': 38.0,
#   'power_pk': 52.0,
#   'model_text': 'Chevrolet Matiz',
#   'model_type': '0.8 S',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '9e628e3c-fd8b-42fb-835c-60bba8c21ea9',
#   'make': 'ford',
#   'model': 'ka/ka+',
#   'first_registration': '09-2010',
#   'fuel_type': 'b',
#   'mileage': 125765.0,
#   'post_code_raw': '1704 RB',
#   'post_code': None,
#   'listing_price': 11.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '51 kW (69 PK)',
#   'power_kw': 51.0,
#   'power_pk': 69.0,
#   'model_text': 'Ford Ka/Ka+',
#   'model_type': '1.2 Cool&Sound | Airco | Electr. ramen | NAP',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'a400e17e-c8f9-4223-99aa-c99aeb7e10c6',
#   'make': 'smart',
#   'model': 'city-coupé/city-cabrio',
#   'first_registration': '10-2000',
#   'fuel_type': 'd',
#   'mileage': 130000.0,
#   'post_code_raw': '5554',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Automatisch',
#   'fuel_text': 'Diesel',
#   'power_text': '30 kW (41 PK)',
#   'power_kw': 30.0,
#   'power_pk': 41.0,
#   'model_text': 'smart city-coupé/city-cabrio',
#   'model_type': 'cdi',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '684063ae-5e32-4ca9-8fbc-3d474824bb65',
#   'make': 'smart',
#   'model': 'fortwo',
#   'first_registration': '04-2005',
#   'fuel_type': 'b',
#   'mileage': 131100.0,
#   'post_code_raw': '3891ZT',
#   'post_code': None,
#   'listing_price': 500.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '45 kW (61 PK)',
#   'power_kw': 45.0,
#   'power_pk': 61.0,
#   'model_text': 'smart forTwo',
#   'model_type': 'forTwo 0.7 passion',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'f5470ce8-faf6-4062-ae14-b17ef486a609',
#   'make': 'peugeot',
#   'model': '106',
#   'first_registration': '05-1995',
#   'fuel_type': 'b',
# ...
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Fiat Panda',
#   'model_type': 'Panda 1.2 Class',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'e4dc8d06-5af8-49fa-beea-e5034befb2c1',
#   'make': 'renault',
#   'model': 'twingo',
#   'first_registration': '02-2003',
#   'fuel_type': 'b',
#   'mileage': 213000.0,
#   'post_code_raw': '4751sz',
#   'post_code': None,
#   'listing_price': 550.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '7 kW (10 PK)',
#   'power_kw': 7.0,
#   'power_pk': 10.0,
#   'model_text': 'Renault Twingo',
#   'model_type': '',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '367ec308-e084-4ae1-8bf7-05e89b197226',
#   'make': 'fiat',
#   'model': 'punto',
#   'first_registration': '03-2001',
#   'fuel_type': 'b',
#   'mileage': 215909.0,
#   'post_code_raw': '7364 BL',
#   'post_code': None,
#   'listing_price': 599.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '59 kW (80 PK)',
#   'power_kw': 59.0,
#   'power_pk': 80.0,
#   'model_text': 'Fiat Punto',
#   'model_type': '1.2-16V ELX INRUILKOOPJE !!!!',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '6995877f-80f9-471f-85f2-4b346f2929a3',
#   'make': 'fiat',
#   'model': 'panda',
#   'first_registration': '01-2008',
#   'fuel_type': 'b',
#   'mileage': 219622.0,
#   'post_code_raw': '1339',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '40 kW (54 PK)',
#   'power_kw': 40.0,
#   'power_pk': 54.0,
#   'model_text': 'Fiat Panda',
#   'model_type': '1.1 Active',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '14793fe3-784a-4aba-8391-313f0dd03456',
#   'make': 'honda',
#   'model': 'jazz',
#   'first_registration': '11-2004',
#   'fuel_type': 'b',
#   'mileage': 218880.0,
#   'post_code_raw': '3769 AD',
#   'post_code': None,
#   'listing_price': 644.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '57 kW (77 PK)',
#   'power_kw': 57.0,
#   'power_pk': 77.0,
#   'model_text': 'Honda Jazz',
#   'model_type': '1.2 5 Deurs, Stuurbekrachtiging',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '800f606d-49e6-4a68-b717-553fee1c6349',
#   'make': 'peugeot',
#   'model': '206',
#   'first_registration': '04-2003',
#   'fuel_type': 'b',
#   'mileage': 215550.0,
#   'post_code_raw': '4142',
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Peugeot 206',
#   'model_type': '1.4 XS Premium',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '4ce716a3-2fae-470b-9e60-f22329247775',
#   'make': 'renault',
#   'model': 'megane',
#   'first_registration': '02-2001',
#   'fuel_type': 'b',
#   'mileage': 212000.0,
#   'post_code_raw': '7545xl',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '79 kW (107 PK)',
#   'power_kw': 79.0,
#   'power_pk': 107.0,
#   'model_text': 'Renault Megane',
#   'model_type': '1.6-16V',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'd68ff0e7-b515-499b-8d28-2ab6d706fb56',
#   'make': 'daewoo',
#   'model': 'kalos',
#   'first_registration': '02-2004',
#   'fuel_type': 'b',
#   'mileage': 212181.0,
#   'post_code_raw': '5223xp',
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '69 kW (94 PK)',
#   'power_kw': 69.0,
#   'power_pk': 94.0,
#   'model_text': 'Daewoo Kalos',
#   'model_type': '1.4 SX',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '623d0a8c-2281-4df6-bd48-60af7fa4b7ef',
#   'make': 'opel',
#   'model': 'zafira',
#   'first_registration': '09-2007',
#   'fuel_type': 'b',
#   'mileage': 216087.0,
#   'post_code_raw': '3812 RB',
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '103 kW (140 PK)',
#   'power_kw': 103.0,
#   'power_pk': 140.0,
#   'model_text': 'Opel Zafira',
#   'model_type': '1.8 Business motor start NIET !!',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '0cbbc9c6-f82f-45a6-8864-c9da210f60db',
#   'make': 'renault',
#   'model': 'scenic',
#   'first_registration': '03-2002',
#   'fuel_type': 'b',
#   'mileage': 219676.0,
#   'post_code_raw': '3769 AD',
#   'post_code': None,
#   'listing_price': 644.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '102 kW (139 PK)',
#   'power_kw': 102.0,
#   'power_pk': 139.0,
#   'model_text': 'Renault Scenic',
#   'model_type': '2.0-16V Expression Airco, NAP, Stuurbekrachtiging,',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'a037d43b-bca5-491d-ac57-b076ee52cde2',
#   'make': 'peugeot',
#   'model': '206',
#   'first_registration': '01-2002',
#   'fuel_type': 'b',
#   'mileage': 220890.0,
#   'post_code_raw': '8224CX',
#   'post_code': None,
#   'listing_price': 550.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Peugeot 206',
#   'model_type': '206 1.4 Gentry',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'b0d03259-465b-4978-9ca9-2e7e97f115e4',
#   'make': 'kia',
#   'model': 'picanto',
#   'first_registration': '09-2005',
#   'fuel_type': 'b',
#   'mileage': 222000.0,
#   'post_code_raw': '3081ZK',
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '45 kW (61 PK)',
#   'power_kw': 45.0,
#   'power_pk': 61.0,
#   'model_text': 'Kia Picanto',
#   'model_type': '1.0 LXE',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '8b6edade-10de-4029-88b9-2dc3bdfbae02',
#   'make': 'volkswagen',
#   'model': 'golf cabriolet',
#   'first_registration': '08-1998',
#   'fuel_type': 'b',
#   'mileage': 224000.0,
#   'post_code_raw': '4311 GL',
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '66 kW (90 PK)',
#   'power_kw': 66.0,
#   'power_pk': 90.0,
#   'model_text': 'Volkswagen Golf Cabriolet',
#   'model_type': 'Cabrio 1.8 Trendline',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '636f4e9d-f36b-4285-915c-383c02c4695f',
#   'make': 'citroen',
#   'model': 'xsara picasso',
#   'first_registration': '03-2004',
#   'fuel_type': 'b',
#   'mileage': 227000.0,
#   'post_code_raw': '8801jt',
#   'post_code': None,
#   'listing_price': 599.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '85 kW (116 PK)',
#   'power_kw': 85.0,
#   'power_pk': 116.0,
#   'model_text': 'Citroen Xsara Picasso',
#   'model_type': 'Xsara Picasso 1.8i-16V 2004 APK 3-2026 NU 599,-',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '96b8bd6a-7bc5-4b2b-9001-a77001fbe662',
#   'make': 'hyundai',
#   'model': 'getz',
#   'first_registration': '07-2003',
#   'fuel_type': 'b',
#   'mileage': 225442.0,
#   'post_code_raw': '1103',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '60 kW (82 PK)',
#   'power_kw': 60.0,
#   'power_pk': 82.0,
#   'model_text': 'Hyundai Getz',
#   'model_type': '1.3 GLS',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '174c5482-3c77-4b83-964e-1e73289c57e1',
#   'make': 'toyota',
#   'model': 'yaris',
#   'first_registration': '11-2005',
#   'fuel_type': 'b',
#   'mileage': 224723.0,
#   'post_code_raw': '5431 XM',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '64 kW (87 PK)',
#   'power_kw': 64.0,
#   'power_pk': 87.0,
#   'model_text': 'Toyota Yaris',
#   'model_type': '1.3 VVT-i Terra',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'b07a54a8-df5b-44dc-9e3a-11575360f286',
#   'make': 'citroen',
#   'model': 'xsara picasso',
#   'first_registration': '12-2003',
#   'fuel_type': 'b',
#   'mileage': 230000.0,
#   'post_code_raw': '7244RR',
#   'post_code': None,
#   'listing_price': 575.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '70 kW (95 PK)',
#   'power_kw': 70.0,
#   'power_pk': 95.0,
#   'model_text': 'Citroen Xsara Picasso',
#   'model_type': '1.6i',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '2ae06e4b-2b78-48b2-a525-74e3b77ed597',
#   'make': 'citroen',
#   'model': 'c4 cactus',
#   'first_registration': '05-2004',
#   'fuel_type': 'b',
#   'mileage': 220855.0,
#   'post_code_raw': '7331kg',
#   'post_code': None,
#   'listing_price': 599.0,
#   'transmission': '- Transmissie',
#   'fuel_text': 'Benzine',
#   'power_text': '80 kW (109 PK)',
#   'power_kw': 80.0,
#   'power_pk': 109.0,
#   'model_text': 'Citroen C4 Cactus',
#   'model_type': 'c2',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '18b079c1-704e-45fb-a744-628ef2018589',
#   'make': 'daewoo',
#   'model': 'kalos',
#   'first_registration': '10-2004',
#   'fuel_type': 'b',
#   'mileage': 230000.0,
#   'post_code_raw': '9561',
#   'post_code': None,
#   'listing_price': 575.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '61 kW (83 PK)',
#   'power_kw': 61.0,
#   'power_pk': 83.0,
#   'model_text': 'Daewoo Kalos',
#   'model_type': '1.4 Spirit',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'e3a91cf9-4168-4fa6-b5c9-b132278f1dfa',
#   'make': 'peugeot',
#   'model': '107',
#   'first_registration': '10-2007',
#   'fuel_type': 'b',
#   'mileage': 228450.0,
#   'post_code_raw': '7544',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '50 kW (68 PK)',
#   'power_kw': 50.0,
#   'power_pk': 68.0,
#   'model_text': 'Peugeot 107',
#   'model_type': '1.0-12V XS',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'd2fcf552-c6f0-4a6f-b585-594792f5964e',
#   'make': 'renault',
#   'model': 'twingo',
#   'first_registration': '06-2001',
#   'fuel_type': 'b',
#   'mileage': 222000.0,
#   'post_code_raw': '2804HW',
#   'post_code': None,
#   'listing_price': 599.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Renault Twingo',
#   'model_type': '1.2-16V Epicéa',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '0f8863c1-0492-449c-9c9f-a039c93f6dd3',
#   'make': 'opel',
#   'model': 'corsa',
#   'first_registration': '01-2007',
#   'fuel_type': 'b',
#   'mileage': 227437.0,
#   'post_code_raw': '1561VJ',
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '59 kW (80 PK)',
#   'power_kw': 59.0,
#   'power_pk': 80.0,
#   'model_text': 'Opel Corsa',
#   'model_type': '1.2 16V Easytronic Sport',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '78060d19-fe8f-4ede-b1f2-5a16574660db',
#   'make': 'volkswagen',
#   'model': 'polo',
#   'first_registration': '01-1996',
#   'fuel_type': 'b',
#   'mileage': 225000.0,
#   'post_code_raw': '5367an',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Volkswagen Polo',
#   'model_type': '75 Servo automaat',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'c2443b59-e524-49fe-baf5-5b26c7ec867e',
#   'make': 'peugeot',
#   'model': '308',
#   'first_registration': '06-2008',
#   'fuel_type': 'b',
#   'mileage': 222222.0,
#   'post_code_raw': '5916sj',
#   'post_code': None,
#   'listing_price': 555.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '110 kW (150 PK)',
#   'power_kw': 110.0,
#   'power_pk': 150.0,
#   'model_text': 'Peugeot 308',
#   'model_type': '1.6 THP XT',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'e55b4b64-8a55-4acc-b3c6-cc313c026d6a',
#   'make': 'renault',
#   'model': 'scenic',
#   'first_registration': '04-2000',
#   'fuel_type': 'b',
#   'mileage': 223653.0,
#   'post_code_raw': '6374VT',
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '102 kW (139 PK)',
#   'power_kw': 102.0,
#   'power_pk': 139.0,
#   'model_text': 'Renault Scenic',
#   'model_type': 'Scenic 2.0-16V RXI',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '37d3cca3-173c-459d-bc76-e33039e294da',
#   'make': 'volkswagen',
#   'model': 'golf',
#   'first_registration': '04-2002',
#   'fuel_type': 'b',
#   'mileage': 228000.0,
#   'post_code_raw': '7601AT',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '77 kW (105 PK)',
#   'power_kw': 77.0,
#   'power_pk': 105.0,
#   'model_text': 'Volkswagen Golf',
#   'model_type': 'Golf 1.6-16V',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '7fc31166-4b0f-450a-a4af-e4346691faf6',
#   'make': 'fiat',
#   'model': 'punto',
#   'first_registration': '10-2001',
#   'fuel_type': 'b',
#   'mileage': 223056.0,
#   'post_code_raw': '5212TM',
#   'post_code': None,
#   'listing_price': 550.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Fiat Punto',
#   'model_type': 'Punto 1.2',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '16ae03e5-9fbe-42fa-a264-70a150fde9a2',
#   'make': 'peugeot',
#   'model': '206',
#   'first_registration': '11-2000',
#   'fuel_type': 'b',
#   'mileage': 226379.0,
#   'post_code_raw': '3071ZK',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '44 kW (60 PK)',
#   'power_kw': 44.0,
#   'power_pk': 60.0,
#   'model_text': 'Peugeot 206',
#   'model_type': '206 1.1 XN',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': 'a4129d45-ca9a-48c7-ab38-9f76b260dbb7',
#   'make': 'bmw',
#   'model': '330',
#   'first_registration': '08-2006',
#   'fuel_type': 'b',
#   'mileage': 240000.0,
#   'post_code_raw': '6043TH',
#   'post_code': None,
#   'listing_price': 600.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '95 kW (129 PK)',
#   'power_kw': 95.0,
#   'power_pk': 129.0,
#   'model_text': 'BMW 330',
#   'model_type': '318i High Executive',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '544a6a44-3ad6-44f6-9524-1cc46a7964f3',
#   'make': 'peugeot',
#   'model': '206',
#   'first_registration': '01-2002',
#   'fuel_type': 'b',
#   'mileage': 236296.0,
#   'post_code_raw': '3751 BG',
#   'post_code': None,
#   'listing_price': 650.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '55 kW (75 PK)',
#   'power_kw': 55.0,
#   'power_pk': 75.0,
#   'model_text': 'Peugeot 206',
#   'model_type': '1.4 Gentry INRUILKOOPJE!',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None},
#  {'car_id': '3ca2d808-c219-4136-8270-520d93000e1c',
#   'make': 'citroen',
#   'model': 'c3',
#   'first_registration': '02-2003',
#   'fuel_type': 'b',
#   'mileage': 235075.0,
#   'post_code_raw': '7103EM',
#   'post_code': None,
#   'listing_price': 599.0,
#   'transmission': 'Handgeschakeld',
#   'fuel_text': 'Benzine',
#   'power_text': '80 kW (109 PK)',
#   'power_kw': 80.0,
#   'power_pk': 109.0,
#   'model_text': 'Citroen C3',
#   'model_type': 'C3 1.6i-16V Exclusive',
#   'range_raw': None,
#   'range_general': None,
#   'range_urban': None}]

# %%
car_ids__ = [d['car_id'] for d in cars_to_insert]

# %%
car_ids__
# Out:
# ['b83278ee-bf4e-409d-b196-a54031118d91',
#  'b83278ee-bf4e-409d-b196-a54031118d91',
#  '99018bd3-90dd-4364-81a4-c0d466a10982',
#  'd1e78be8-fda0-4295-b30d-cbd5ea62b061',
#  '491d36ff-4e79-404b-b37b-361a6032d9d3',
#  'f69b3dbe-d9b8-43a2-b87a-af6a5f0107e0',
#  '7fd664f3-c601-4af7-b07f-fe5d4edc7e27',
#  'e11833cd-1eca-472d-b6aa-ae2408ea2f63',
#  '848558a2-3863-44a2-a8ac-9be019f8ad95',
#  '8d6f7363-500a-4541-a40c-aae3b69281a6',
#  '1c8d1151-6a89-4f47-8c9d-3b53fcbf65a6',
#  '83c5f616-87b3-47f7-9593-c3200563d9f6',
#  'f2e869c6-e5d2-4ae7-b5e0-f9e229221be9',
#  '657bbb85-da4a-490e-8ad7-4c66bbbd0f8f',
#  '1f751005-2c17-44a1-acbb-918f243397b5',
#  '4e0991a6-bd16-4c44-9811-c8a452af270f',
#  '46108157-e9bc-4749-ba84-d4a9515c3d69',
#  '3ab61b19-75f9-4459-be97-1f87353759c9',
#  'e9f2ff14-ac0b-44ef-b28b-25f5e8392656',
#  '531d61ca-7929-4c71-bf64-92987e832556',
#  'c66d3815-e428-4f6f-881e-32414089c909',
#  '82ecba56-2451-49ad-90fc-e7813acc8784',
#  '324411e9-1db9-4c13-96b8-4440e8d1430f',
#  'e4dc8d06-5af8-49fa-beea-e5034befb2c1',
#  '367ec308-e084-4ae1-8bf7-05e89b197226',
#  '6995877f-80f9-471f-85f2-4b346f2929a3',
#  '14793fe3-784a-4aba-8391-313f0dd03456',
#  '800f606d-49e6-4a68-b717-553fee1c6349',
#  '4ce716a3-2fae-470b-9e60-f22329247775',
#  'd68ff0e7-b515-499b-8d28-2ab6d706fb56',
#  '623d0a8c-2281-4df6-bd48-60af7fa4b7ef',
#  '0cbbc9c6-f82f-45a6-8864-c9da210f60db',
#  'a037d43b-bca5-491d-ac57-b076ee52cde2',
#  'b0d03259-465b-4978-9ca9-2e7e97f115e4',
#  '8b6edade-10de-4029-88b9-2dc3bdfbae02',
#  '636f4e9d-f36b-4285-915c-383c02c4695f',
#  '96b8bd6a-7bc5-4b2b-9001-a77001fbe662',
#  '174c5482-3c77-4b83-964e-1e73289c57e1',
#  'b07a54a8-df5b-44dc-9e3a-11575360f286',
#  '2ae06e4b-2b78-48b2-a525-74e3b77ed597',
#  '18b079c1-704e-45fb-a744-628ef2018589',
#  'e3a91cf9-4168-4fa6-b5c9-b132278f1dfa',
#  'd2fcf552-c6f0-4a6f-b585-594792f5964e',
#  '0f8863c1-0492-449c-9c9f-a039c93f6dd3',
#  '78060d19-fe8f-4ede-b1f2-5a16574660db',
#  'c2443b59-e524-49fe-baf5-5b26c7ec867e',
#  'e55b4b64-8a55-4acc-b3c6-cc313c026d6a',
#  '37d3cca3-173c-459d-bc76-e33039e294da',
#  '7fc31166-4b0f-450a-a4af-e4346691faf6',
#  '16ae03e5-9fbe-42fa-a264-70a150fde9a2',
#  'a4129d45-ca9a-48c7-ab38-9f76b260dbb7',
#  '544a6a44-3ad6-44f6-9524-1cc46a7964f3',
#  '3ca2d808-c219-4136-8270-520d93000e1c']

# %%
len(car_ids__)
# Out:
# 501

# %%
count_added

# %%
response = supabase.table(table_name).select("car_id").execute()
car_ids_in_database = response.data

# %%
df = pd.DataFrame([d['car_id'] for d in car_ids_in_database])

# %%
len(df[0].unique()) - len(df)

# %% [markdown]
# ## Remove duplicates in database

# %%
response = supabase.table(table_name).select("id, car_id, make, listing_price").execute()
car_ids_in_database = response.data

# %%
df_full = pd.DataFrame(car_ids_in_database)

# %%
df_full
# Out:
#             id                                car_id           make  \
# 0        77546  68936f70-81e9-4387-ad5c-ac6eed1f5438         nissan
# 1          151  0d92d6f1-39e5-4606-b239-1eafa1eb65f2           fiat
# 2          152  e148c182-bfdc-4820-befa-b7f8bb3569fe  mercedes-benz
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.52s/it]

# %% [markdown]
# ## Check latitude and longitude

# %%
BASE_URL = "https://openpostcode.nl/api/address"

params = {
    "postcode": "1011AB",
    "huisnummer": '99'
}

response = requests.get(BASE_URL, params=params)

# %%
response.json()
# Out:
# {'postcode': '1011AB',
#  'huisnummer': '99',
#  'straat': 'De Ruijterkade',
#  'buurt': 'Oosterdokseiland',
#  'wijk': 'Nieuwmarkt/Lastage',
#  'woonplaats': 'Amsterdam',
#  'gemeente': 'Amsterdam',
#  'provincie': 'Noord-Holland',
#  'latitude': 52.378666,
#  'longitude': 4.9054437}

# %% [markdown]
# ## Check post code convention

# %%
def is_valid_format(s, pattern):
    return bool(re.fullmatch(pattern, s))

# %%
response = supabase.table(table_name).select("id, car_id, post_code, post_code_raw").execute()

# %%
df_full = pd.DataFrame(response.data)

# %%
df_full['post_code'].sort_values().unique()
# Out:
# array(['0000AA', '0000AB', '0000OO', ..., '9997PG', '9998NZ', None],
#       shape=(31130,), dtype=object)

# %%
df_full
# Out:
#             id                                car_id post_code post_code_raw
# 0        77546  68936f70-81e9-4387-ad5c-ac6eed1f5438    8281PC       8281 PC
# 1          151  0d92d6f1-39e5-4606-b239-1eafa1eb65f2    2987VD       2987 VD
# 2          152  e148c182-bfdc-4820-befa-b7f8bb3569fe    7903BM       7903 BM
# 3          153  ac97cde6-8a38-4dca-a30a-bfb2286cb9ea    7513EL       7513 EL
# 4          154  99c8af8d-6633-46c2-81e3-012d73c34c8b    5505JA       5505 JA
# ...        ...                                   ...       ...           ...
# 268541  276040  acf0832f-293c-4ac5-a276-fbf410baa346    5161CB       5161 CB
# 268542  276041  761a9158-01b3-4044-95ee-7e5ae70b40ad    2988AD       2988 AD
# 268543  276042  cec055f4-e88a-4965-9238-a226e6313057    7943KC        7943KC
# 268544  276043  8bc1bca9-2ba0-4294-b80b-3a919effa566    9482RD        9482rd
# 268545  276045  eb4e6a7d-28dc-44b3-983b-00dfa7880047    7671DA       7671 DA
#
# [268546 rows x 4 columns]

# %%
batch_size = 100  # choose a batch size to avoid huge payloads
updates = []

for index, row in tqdm(df_full.iterrows(), total=df_full.shape[0]):
    if row['post_code']:  # skip if already set
        continue
    
    raw_postcode = row['post_code_raw']
    
    # Compute formatted postcode
    try:
        postcode = raw_postcode[0:4] + raw_postcode[-2:].upper()
        if not is_valid_format(postcode, pattern):
            postcode = None
    except Exception as e:
        postcode = None
    
    # Append to batch list
    updates.append({"id": row['id'], "post_code": postcode})
    
    # When batch is full, send to Supabase
    if len(updates) >= batch_size:
        supabase.table(table_name).upsert(updates).execute()
        updates = []  # clear batch

# Send remaining updates if any
if updates:
    supabase.table(table_name).upsert(updates).execute()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 268546/268546 [05:58<00:00, 749.33it/s]

# %%
BASE_URL = "https://openpostcode.nl/api/address"

params = {
    "postcode": "4167BM",
    "huisnummer": '1'
}

response = requests.get(BASE_URL, params=params)

# %%
response.text
# Out:
# '{"error":"Postcode not found"}\n'
