# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
from tqdm import tqdm
import time
import string
import itertools
import subprocess
from dotenv import load_dotenv
import logging
import os
import numpy as np
from bs4 import BeautifulSoup
import requests
from supabase import create_client, Client
import json
from dotenv import load_dotenv
from rich.console import Console
from rich.progress import Progress, BarColumn, TextColumn, TimeRemainingColumn
from datetime import datetime
import re
import random

# %%
# Load variables from .env into the environment
load_dotenv()

# Read variables
supabase_url = os.getenv("SUPABASE_URL")
supabase_key = os.getenv("SUPABASE_KEY")

# %%
# Initialize client
supabase: Client = create_client(supabase_url, supabase_key)

# %%
# # Example: Check status
# command = r'cd "C:\Program Files\NordVPN" && nordvpn -c -g "Netherlands"'
# result = subprocess.run(command, shell=True, capture_output=True, text=True)
# time.sleep(5)

# %%
BASE_URL = "https://openpostcode.nl/api/address"

params = {
    "postcode": "5056TG",
    "huisnummer": '23'
}

response = requests.get(BASE_URL, params=params)

# %%
response.status_code
# Out:
# 200

# %%
car_adverts_table = 'autoscout_car_adverts'
response = supabase.table(car_adverts_table).select("car_id, post_code").not_.is_("post_code","null").execute()
df_full = pd.DataFrame(response.data)
postcodes_in_car_database = set(df_full['post_code'])

# %%
def fetch_all_rows_in_batches(
    supabase,
    table_name: str,
    columns: str = "*",
    batch_size: int = 5000,
    max_batches: int | None = None
):
    """
    Fetch all rows from a Supabase table in batches to avoid timeouts.

    Args:
        supabase: Supabase client instance
        table_name: Name of the table to query
        columns: Comma-separated column names or "*" for all
        batch_size: Number of rows per batch
        max_batches: Optional limit (for testing or large tables)

    Returns:
        List of dicts containing all rows fetched.
    """
    all_rows = []
    offset = 0
    batch_count = 0

    while True:
        try:
            response = (
                supabase.table(table_name)
                .select(columns)
                .range(offset, offset + batch_size - 1)
                .execute()
            )

            data = response.data

            # Stop when no more rows
            if not data:
                logging.info(f"No more rows after offset {offset}.")
                break

            all_rows.extend(data)
            offset += batch_size
            batch_count += 1

            logging.info(f"Fetched {len(data)} rows (total {len(all_rows)}).")

            # Optional: stop early if max_batches is set
            if max_batches and batch_count >= max_batches:
                logging.info(f"Reached max_batches ({max_batches}), stopping early.")
                break

        except Exception as e:
            logging.error(f"Error fetching batch starting at {offset}: {e}")
            time.sleep(2)
            break

    return all_rows

# %%
tmp = fetch_all_rows_in_batches(supabase, car_adverts_table, "car_id, post_code", 50000)

# %%
pd.DataFrame(tmp)
# Out:
#                                       car_id post_code
# 0       54160968-7f61-40e3-aa01-d8a144e43778    7447JK
# 1       83fc4c33-72c9-41a0-933f-b481bfb52dc3    4815PN
# 2       ed521553-6242-4a23-bdc0-be20ab80b189    1327GE
# 3       f03e55e9-9ff1-49f5-8dc9-99c56f53b1f2    5141PB
# 4       3ff5f15f-c976-440a-b617-22bb1dd6832d    5161PA
# ...                                      ...       ...
# 431410  859fa688-a00f-4c39-8a71-5dddfd8b2d95    5741SX
# 431411  4b15e529-82db-4870-9adf-326bc2e315d2    5741SX
# 431412  2ad04bdd-4f4c-4c04-bc03-bfe89186c06a    5469NM
# 431413  c14feb83-0843-4c0f-85fd-00f01b049670    7333NS
# 431414  da15e625-b9c5-47cf-935e-196d01729e2a    3421TX
#
# [431415 rows x 2 columns]

# %%
postcodes_table = 'postcode_info_nl'
response = supabase.table(postcodes_table).select("post_code", "latitude").not_.is_("latitude","null").execute()
df_full = pd.DataFrame(response.data)
postcodes_in_database = set(df_full['post_code'])

# %%
len(postcodes_in_database)
# Out:
# 42663

# %%
len(postcodes_in_car_database)
# Out:
# 42143

# %%
postcodes_not_in_database = postcodes_in_car_database.difference(postcodes_in_database)

# %%
len(postcodes_not_in_database)
# Out:
# 660

# %%
import multiprocessing

num_cores = multiprocessing.cpu_count()
print(f"CPU cores available: {num_cores}")
# Out:
# CPU cores available: 8

# %%
# Initialize a rich Console object
console = Console()

batch_size = 100
postcodes_to_insert = []
count_added = 0

# Loop through all combinations (generator approach)
try:
    for code in tqdm(postcodes_in_car_database):
        if code in postcodes_in_database:
            continue
        
        # print(code)  # or process it
        params = {
            "postcode": code,
            "huisnummer": 1
        }
        response = requests.get(BASE_URL, params=params)
        if response.status_code == 500  or response.status_code == 429:
            # command = r'cd "C:\Program Files\NordVPN" && nordvpn -c -g "Netherlands"'
            # result = subprocess.run(command, shell=True, capture_output=True, text=True)
            # time.sleep(10)
            # response = requests.get(BASE_URL, params=params)
            # console.log(f"Reconnecting VPN...")
            # raise Exception("Too many requests.")
            continue
        
        elif 'latitude' and 'longitude' in response.json().keys():
            lat = response.json()['latitude']
            lon = response.json()['longitude']
            straat = response.json()['straat']
            buurt = response.json()['buurt']
            wijk = response.json()['wijk']
            woonplaats = response.json()['woonplaats']
            gemeente = response.json()['gemeente']
            provincie = response.json()['provincie']
            huisnummer = response.json()['huisnummer']
            
        elif response.json()['error'] == 'Huisnummer not found':
            params = {
                "postcode": code,
                "huisnummer": response.json()['suggestions'][0]
            }
            response = requests.get(BASE_URL, params=params)
            if response.status_code == 500  or response.status_code == 429:
                # command = r'cd "C:\Program Files\NordVPN" && nordvpn -c -g "Netherlands"'
                # result = subprocess.run(command, shell=True, capture_output=True, text=True)
                # time.sleep(10)
                # response = requests.get(BASE_URL, params=params)
                # console.log(f"Reconnecting VPN...")
                # raise Exception("Too many requests.")
                continue
            lat = response.json()['latitude']
            lon = response.json()['longitude']
            straat = response.json()['straat']
            buurt = response.json()['buurt']
            wijk = response.json()['wijk']
            woonplaats = response.json()['woonplaats']
            gemeente = response.json()['gemeente']
            provincie = response.json()['provincie']
            huisnummer = response.json()['huisnummer']
        # elif response.status_code == 429:
        #     # subprocess.run(["nordvpn", "disconnect", "Netherlands"])
        #     # time.sleep(1)
        #     # subprocess.run(["nordvpn", "connect", "Netherlands"])
        #     break
        else:
            lat = None
            lon = None
            straat = None
            buurt = None
            wijk = None
            woonplaats = None
            gemeente = None
            provincie = None
            huisnummer = None
            
        postcode_info = {
            "post_code": code,
            "huisnummer": huisnummer,
            "straat": straat,
            "buurt": buurt,
            "wijk": wijk,
            "woonplaats": woonplaats,
            "gemeente": gemeente,
            "provincie": provincie,
            "longitude": lon,
            "latitude": lat,
        }
        postcodes_to_insert.append(postcode_info)
        postcodes_in_database.add(code)
        time.sleep(random.uniform(0.01, 0.05))
        if len(postcodes_to_insert) >= batch_size:
            console.log(f"Inserting {len(postcodes_to_insert)} postcodes to the database...")
            supabase.table(postcodes_table).upsert(postcodes_to_insert).execute()
            count_added += len(postcodes_to_insert)
            postcodes_to_insert = []

    if postcodes_to_insert:
        console.log(f"Inserting final {len(postcodes_to_insert)} cars to the database...")
        supabase.table(postcodes_table).upsert(postcodes_to_insert).execute()
        count_added += len(postcodes_to_insert)
    
except requests.exceptions.RequestException as e:
    
    if postcodes_to_insert:
        console.log(f"Inserting final {len(postcodes_to_insert)} cars to the database...")
        supabase.table(postcodes_table).upsert(postcodes_to_insert).execute()
        count_added += len(postcodes_to_insert)
        raise SystemExit(e)
# Out:
#  14%|████████████████████████████                                                                                                                                                                              | 5807/41770 [00:23<01:32, 389.25it/s]
# [22:28:22] Inserting 100 postcodes to the database...                                              ]8;id=966708;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py\1261536160.py]8;;\:]8;id=279293;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py#95\95]8;;\
#  29%|█████████████████████████████████████████████████████████▍                                                                                                                                               | 11946/41770 [00:37<00:38, 768.68it/s]
# [22:28:35] Inserting 100 postcodes to the database...                                              ]8;id=81126;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py\1261536160.py]8;;\:]8;id=846882;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py#95\95]8;;\
#  44%|████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                | 18333/41770 [00:54<01:01, 380.53it/s]
# [22:28:52] Inserting 100 postcodes to the database...                                              ]8;id=507708;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py\1261536160.py]8;;\:]8;id=905732;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py#95\95]8;;\
#  59%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                 | 24772/41770 [01:07<00:39, 431.85it/s]
# [22:29:06] Inserting 100 postcodes to the database...                                              ]8;id=152018;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py\1261536160.py]8;;\:]8;id=543798;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py#95\95]8;;\
#  75%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                 | 31473/41770 [01:20<00:10, 937.93it/s]
# [22:29:20] Inserting 100 postcodes to the database...                                              ]8;id=736839;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py\1261536160.py]8;;\:]8;id=645628;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py#95\95]8;;\
#  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                | 38290/41770 [01:33<00:05, 583.08it/s]
# [22:29:32] Inserting 100 postcodes to the database...                                              ]8;id=134589;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py\1261536160.py]8;;\:]8;id=433646;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py#95\95]8;;\
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41770/41770 [01:38<00:00, 423.08it/s]
# [22:29:37] Inserting final 14 cars to the database...                                             ]8;id=795590;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py\1261536160.py]8;;\:]8;id=235207;file://C:\Users\david\AppData\Local\Temp\ipykernel_16280\1261536160.py#101\101]8;;\

# %%
response
# Out:
# APIResponse[~_ReturnT](data=[{'post_code': '1011AB', 'latitude': 52.378666}, {'post_code': '1011AC', 'latitude': 52.377644}, {'post_code': '1011AD', 'latitude': 52.37682}, {'post_code': '1011AE', 'latitude': 52.3757}, {'post_code': '1011AG', 'latitude': 52.375946}, {'post_code': '1011AH', 'latitude': 52.37576}, {'post_code': '1011AJ', 'latitude': 52.375534}, {'post_code': '1011AK', 'latitude': 52.374645}, {'post_code': '1011AL', 'latitude': 52.36883}, {'post_code': '1011AM', 'latitude': 52.374218}, {'post_code': '1011AN', 'latitude': 52.374073}, {'post_code': '1011AP', 'latitude': 52.373943}, {'post_code': '1011AR', 'latitude': 52.3738}, {'post_code': '1011AS', 'latitude': 52.373497}, {'post_code': '1011AT', 'latitude': 52.373352}, {'post_code': '1011AV', 'latitude': 52.373158}, {'post_code': '1011AW', 'latitude': 52.373005}, {'post_code': '1011AX', 'latitude': 52.374126}, {'post_code': '1011AZ', 'latitude': 52.373497}, {'post_code': '1011BA', 'latitude': 52.373558}, {'post_code': '1011BB', 'latitude': 52.373405}, {'post_code': '1011BC', 'latitude': 52.37288}, {'post_code': '1011BD', 'latitude': 52.37269}, {'post_code': '1011BG', 'latitude': 52.37491}, {'post_code': '1011BH', 'latitude': 52.37374}, {'post_code': '1011BJ', 'latitude': 52.37349}, {'post_code': '1011BK', 'latitude': 52.373276}, {'post_code': '1011BL', 'latitude': 52.373135}, {'post_code': '1011BM', 'latitude': 52.373043}, {'post_code': '1011BN', 'latitude': 52.37293}, {'post_code': '1011BP', 'latitude': 52.372814}, {'post_code': '1011BR', 'latitude': 52.37267}, {'post_code': '1011BS', 'latitude': 52.375233}, {'post_code': '1011BT', 'latitude': 52.374775}, {'post_code': '1011BV', 'latitude': 52.37437}, {'post_code': '1011BW', 'latitude': 52.373966}, {'post_code': '1011BX', 'latitude': 52.373455}, {'post_code': '1011BZ', 'latitude': 52.37326}, {'post_code': '1011CA', 'latitude': 52.373028}, {'post_code': '1011CB', 'latitude': 52.37287}, {'post_code': '1011CC', 'latitude': 52.372547}, {'post_code': '1011CD', 'latitude': 52.372368}, {'post_code': '1011CE', 'latitude': 52.372227}, {'post_code': '1011CH', 'latitude': 52.37398}, {'post_code': '1011CJ', 'latitude': 52.37376}, {'post_code': '1011CK', 'latitude': 52.37392}, {'post_code': '1011CL', 'latitude': 52.373768}, {'post_code': '1011CM', 'latitude': 52.37361}, {'post_code': '1011CN', 'latitude': 52.373577}, {'post_code': '1011CP', 'latitude': 52.37355}, {'post_code': '1011CR', 'latitude': 52.373398}, {'post_code': '1011CS', 'latitude': 52.37297}, {'post_code': '1011CT', 'latitude': 52.37271}, {'post_code': '1011CV', 'latitude': 52.37255}, {'post_code': '1011CW', 'latitude': 52.37229}, {'post_code': '1011CX', 'latitude': 52.37213}, {'post_code': '1011CZ', 'latitude': 52.37196}, {'post_code': '1011DB', 'latitude': 52.373394}, {'post_code': '1011DC', 'latitude': 52.37155}, {'post_code': '1011DD', 'latitude': 52.376072}, {'post_code': '1011DE', 'latitude': 52.375614}, {'post_code': '1011DG', 'latitude': 52.375904}, {'post_code': '1011DH', 'latitude': 52.376293}, {'post_code': '1011DJ', 'latitude': 52.376648}, {'post_code': '1011DK', 'latitude': 52.376923}, {'post_code': '1011DL', 'latitude': 52.37625}, {'post_code': '1011DZ', 'latitude': 52.371796}, {'post_code': '1011EA', 'latitude': 52.37316}, {'post_code': '1011EB', 'latitude': 52.372673}, {'post_code': '1011EC', 'latitude': 52.37234}, {'post_code': '1011ED', 'latitude': 52.37176}, {'post_code': '1011EE', 'latitude': 52.37269}, {'post_code': '1011EG', 'latitude': 52.37274}, {'post_code': '1011EH', 'latitude': 52.375946}, {'post_code': '1011EJ', 'latitude': 52.375397}, {'post_code': '1011EK', 'latitude': 52.37512}, {'post_code': '1011EL', 'latitude': 52.374504}, {'post_code': '1011EM', 'latitude': 52.373955}, {'post_code': '1011EN', 'latitude': 52.3732}, {'post_code': '1011ER', 'latitude': 52.374226}, {'post_code': '1011ES', 'latitude': 52.372795}, {'post_code': '1011ET', 'latitude': 52.372517}, {'post_code': '1011EV', 'latitude': 52.372658}, {'post_code': '1011EW', ' ...

# %%
response.data
# Out:
# [{'post_code': '1011AB', 'latitude': 52.378666},
#  {'post_code': '1011AC', 'latitude': 52.377644},
#  {'post_code': '1011AD', 'latitude': 52.37682},
#  {'post_code': '1011AE', 'latitude': 52.3757},
#  {'post_code': '1011AG', 'latitude': 52.375946},
#  {'post_code': '1011AH', 'latitude': 52.37576},
#  {'post_code': '1011AJ', 'latitude': 52.375534},
#  {'post_code': '1011AK', 'latitude': 52.374645},
#  {'post_code': '1011AL', 'latitude': 52.36883},
#  {'post_code': '1011AM', 'latitude': 52.374218},
#  {'post_code': '1011AN', 'latitude': 52.374073},
#  {'post_code': '1011AP', 'latitude': 52.373943},
#  {'post_code': '1011AR', 'latitude': 52.3738},
#  {'post_code': '1011AS', 'latitude': 52.373497},
#  {'post_code': '1011AT', 'latitude': 52.373352},
#  {'post_code': '1011AV', 'latitude': 52.373158},
#  {'post_code': '1011AW', 'latitude': 52.373005},
#  {'post_code': '1011AX', 'latitude': 52.374126},
#  {'post_code': '1011AZ', 'latitude': 52.373497},
#  {'post_code': '1011BA', 'latitude': 52.373558},
#  {'post_code': '1011BB', 'latitude': 52.373405},
#  {'post_code': '1011BC', 'latitude': 52.37288},
#  {'post_code': '1011BD', 'latitude': 52.37269},
#  {'post_code': '1011BG', 'latitude': 52.37491},
#  {'post_code': '1011BH', 'latitude': 52.37374},
#  {'post_code': '1011BJ', 'latitude': 52.37349},
#  {'post_code': '1011BK', 'latitude': 52.373276},
#  {'post_code': '1011BL', 'latitude': 52.373135},
#  {'post_code': '1011BM', 'latitude': 52.373043},
#  {'post_code': '1011BN', 'latitude': 52.37293},
#  {'post_code': '1011BP', 'latitude': 52.372814},
#  {'post_code': '1011BR', 'latitude': 52.37267},
#  {'post_code': '1011BS', 'latitude': 52.375233},
#  {'post_code': '1011BT', 'latitude': 52.374775},
#  {'post_code': '1011BV', 'latitude': 52.37437},
#  {'post_code': '1011BW', 'latitude': 52.373966},
#  {'post_code': '1011BX', 'latitude': 52.373455},
#  {'post_code': '1011BZ', 'latitude': 52.37326},
#  {'post_code': '1011CA', 'latitude': 52.373028},
#  {'post_code': '1011CB', 'latitude': 52.37287},
#  {'post_code': '1011CC', 'latitude': 52.372547},
#  {'post_code': '1011CD', 'latitude': 52.372368},
#  {'post_code': '1011CE', 'latitude': 52.372227},
#  {'post_code': '1011CH', 'latitude': 52.37398},
#  {'post_code': '1011CJ', 'latitude': 52.37376},
#  {'post_code': '1011CK', 'latitude': 52.37392},
#  {'post_code': '1011CL', 'latitude': 52.373768},
#  {'post_code': '1011CM', 'latitude': 52.37361},
#  {'post_code': '1011CN', 'latitude': 52.373577},
#  {'post_code': '1011CP', 'latitude': 52.37355},
#  {'post_code': '1011CR', 'latitude': 52.373398},
#  {'post_code': '1011CS', 'latitude': 52.37297},
#  {'post_code': '1011CT', 'latitude': 52.37271},
#  {'post_code': '1011CV', 'latitude': 52.37255},
#  {'post_code': '1011CW', 'latitude': 52.37229},
#  {'post_code': '1011CX', 'latitude': 52.37213},
#  {'post_code': '1011CZ', 'latitude': 52.37196},
#  {'post_code': '1011DB', 'latitude': 52.373394},
#  {'post_code': '1011DC', 'latitude': 52.37155},
#  {'post_code': '1011DD', 'latitude': 52.376072},
#  {'post_code': '1011DE', 'latitude': 52.375614},
#  {'post_code': '1011DG', 'latitude': 52.375904},
#  {'post_code': '1011DH', 'latitude': 52.376293},
#  {'post_code': '1011DJ', 'latitude': 52.376648},
#  {'post_code': '1011DK', 'latitude': 52.376923},
#  {'post_code': '1011DL', 'latitude': 52.37625},
#  {'post_code': '1011DZ', 'latitude': 52.371796},
#  {'post_code': '1011EA', 'latitude': 52.37316},
#  {'post_code': '1011EB', 'latitude': 52.372673},
#  {'post_code': '1011EC', 'latitude': 52.37234},
#  {'post_code': '1011ED', 'latitude': 52.37176},
#  {'post_code': '1011EE', 'latitude': 52.37269},
#  {'post_code': '1011EG', 'latitude': 52.37274},
#  {'post_code': '1011EH', 'latitude': 52.375946},
#  {'post_code': '1011EJ', 'latitude': 52.375397},
#  {'post_code': '1011EK', 'latitude': 52.37512},
#  {'post_code': '1011EL', 'latitude': 52.374504},
#  {'post_code': '1011EM', 'latitude': 52.373955},
#  {'post_code': '1011EN', 'latitude': 52.3732},
#  {'post_code': '1011ER', 'latitude': 52.374226},
#  {'post_code': '1011ES', 'latitude': 52.372795},
#  {'post_code': '1011ET', 'latitude': 52.372517},
#  {'post_code': '1011EV', 'latitude': 52.372658},
#  {'post_code': '1011EW', 'latitude': 52.372498},
#  {'post_code': '1011EX', 'latitude': 52.37193},
#  {'post_code': '1011EZ', 'latitude': 52.371597},
#  {'post_code': '1011GA', 'latitude': 52.371864},
#  {'post_code': '1011GB', 'latitude': 52.37177},
#  {'post_code': '1011GC', 'latitude': 52.371788},
#  {'post_code': '1011GD', 'latitude': 52.372314},
#  {'post_code': '1011GG', 'latitude': 52.37146},
#  {'post_code': '1011GH', 'latitude': 52.371315},
#  {'post_code': '1011GJ', 'latitude': 52.37157},
#  {'post_code': '1011GK', 'latitude': 52.371243},
#  {'post_code': '1011GL', 'latitude': 52.371696},
#  {'post_code': '1011GM', 'latitude': 52.370872},
#  {'post_code': '1011GN', 'latitude': 52.372803},
#  {'post_code': '1011GP', 'latitude': 52.372223},
#  {'post_code': '1011GR', 'latitude': 52.372055},
#  {'post_code': '1011GS', 'latitude': 52.37136},
#  {'post_code': '1011GT', 'latitude': 52.37092},
#  {'post_code': '1011GV', 'latitude': 52.372467},
#  {'post_code': '1011GW', 'latitude': 52.372017},
#  {'post_code': '1011GX', 'latitude': 52.371483},
#  {'post_code': '1011GZ', 'latitude': 52.370716},
#  {'post_code': '1011HA', 'latitude': 52.37057},
#  {'post_code': '1011HB', 'latitude': 52.37189},
#  {'post_code': '1011HC', 'latitude': 52.37096},
#  {'post_code': '1011HD', 'latitude': 52.370773},
#  {'post_code': '1011HE', 'latitude': 52.370827},
#  {'post_code': '1011HG', 'latitude': 52.370632},
#  {'post_code': '1011HH', 'latitude': 52.37063},
#  {'post_code': '1011HJ', 'latitude': 52.370358},
#  {'post_code': '1011HK', 'latitude': 52.370247},
#  {'post_code': '1011HL', 'latitude': 52.370144},
#  {'post_code': '1011HM', 'latitude': 52.370594},
#  {'post_code': '1011HN', 'latitude': 52.370045},
#  {'post_code': '1011HP', 'latitude': 52.370647},
#  {'post_code': '1011HR', 'latitude': 52.36956},
#  {'post_code': '1011HS', 'latitude': 52.368946},
#  {'post_code': '1011HT', 'latitude': 52.36816},
#  {'post_code': '1011HV', 'latitude': 52.36949},
#  {'post_code': '1011HW', 'latitude': 52.36905},
#  {'post_code': '1011HX', 'latitude': 52.36815},
#  {'post_code': '1011HZ', 'latitude': 52.369335},
#  {'post_code': '1011JA', 'latitude': 52.36937},
#  {'post_code': '1011JB', 'latitude': 52.370052},
#  {'post_code': '1011JC', 'latitude': 52.36952},
#  {'post_code': '1011JD', 'latitude': 52.369164},
#  {'post_code': '1011JE', 'latitude': 52.371567},
#  {'post_code': '1011JG', 'latitude': 52.36905},
#  {'post_code': '1011JH', 'latitude': 52.368977},
#  {'post_code': '1011JJ', 'latitude': 52.368355},
#  {'post_code': '1011JK', 'latitude': 52.368275},
#  {'post_code': '1011JL', 'latitude': 52.368237},
#  {'post_code': '1011JM', 'latitude': 52.368202},
#  {'post_code': '1011JN', 'latitude': 52.36765},
#  {'post_code': '1011JP', 'latitude': 52.372692},
#  {'post_code': '1011JR', 'latitude': 52.372524},
#  {'post_code': '1011JS', 'latitude': 52.372368},
#  {'post_code': '1011JT', 'latitude': 52.37198},
#  {'post_code': '1011JV', 'latitude': 52.371674},
#  {'post_code': '1011JW', 'latitude': 52.370842},
#  {'post_code': '1011JX', 'latitude': 52.37059},
#  {'post_code': '1011JZ', 'latitude': 52.37022},
#  {'post_code': '1011KA', 'latitude': 52.36965},
#  {'post_code': '1011KB', 'latitude': 52.3692},
#  {'post_code': '1011KC', 'latitude': 52.368687},
#  {'post_code': '1011KD', 'latitude': 52.368237},
#  {'post_code': '1011KE', 'latitude': 52.368008},
#  {'post_code': '1011KH', 'latitude': 52.37002},
#  {'post_code': '1011KJ', 'latitude': 52.36975},
#  {'post_code': '1011KK', 'latitude': 52.369743},
#  {'post_code': '1011KM', 'latitude': 52.3678},
#  {'post_code': '1011KN', 'latitude': 52.367825},
#  {'post_code': '1011KP', 'latitude': 52.371635},
#  {'post_code': '1011KR', 'latitude': 52.37149},
#  {'post_code': '1011KS', 'latitude': 52.37135},
#  {'post_code': '1011KT', 'latitude': 52.371082},
#  {'post_code': '1011KV', 'latitude': 52.3708},
#  {'post_code': '1011KW', 'latitude': 52.37071},
#  {'post_code': '1011KX', 'latitude': 52.372047},
#  {'post_code': '1011KZ', 'latitude': 52.372017},
#  {'post_code': '1011LA', 'latitude': 52.371826},
#  {'post_code': '1011LB', 'latitude': 52.371567},
#  {'post_code': '1011LC', 'latitude': 52.37133},
#  {'post_code': '1011LD', 'latitude': 52.371212},
#  {'post_code': '1011LE', 'latitude': 52.370823},
#  {'post_code': '1011LH', 'latitude': 52.37168},
#  {'post_code': '1011LJ', 'latitude': 52.37074},
#  {'post_code': '1011LK', 'latitude': 52.37054},
#  {'post_code': '1011LL', 'latitude': 52.370026},
#  {'post_code': '1011LM', 'latitude': 52.37132},
#  {'post_code': '1011LN', 'latitude': 52.37009},
#  {'post_code': '1011LP', 'latitude': 52.37142},
#  {'post_code': '1011LR', 'latitude': 52.371243},
#  {'post_code': '1011LS', 'latitude': 52.371098},
#  {'post_code': '1011LT', 'latitude': 52.370987},
#  {'post_code': '1011LV', 'latitude': 52.370815},
#  {'post_code': '1011LW', 'latitude': 52.370663},
#  {'post_code': '1011LX', 'latitude': 52.37028},
#  {'post_code': '1011LZ', 'latitude': 52.370514},
#  {'post_code': '1011MA', 'latitude': 52.37201},
#  {'post_code': '1011MB', 'latitude': 52.37201},
#  {'post_code': '1011MC', 'latitude': 52.371014},
#  {'post_code': '1011ME', 'latitude': 52.372105},
#  {'post_code': '1011MG', 'latitude': 52.36993},
#  {'post_code': '1011MH', 'latitude': 52.36952},
#  {'post_code': '1011MJ', 'latitude': 52.369164},
#  {'post_code': '1011MK', 'latitude': 52.369644},
#  {'post_code': '1011ML', 'latitude': 52.36918},
#  {'post_code': '1011MN', 'latitude': 52.368843},
#  {'post_code': '1011MP', 'latitude': 52.36973},
#  {'post_code': '1011MR', 'latitude': 52.36927},
#  {'post_code': '1011MS', 'latitude': 52.36724},
#  {'post_code': '1011MT', 'latitude': 52.368824},
#  {'post_code': '1011MV', 'latitude': 52.36839},
#  {'post_code': '1011MX', 'latitude': 52.370228},
#  {'post_code': '1011MZ', 'latitude': 52.37012},
#  {'post_code': '1011NA', 'latitude': 52.36977},
#  {'post_code': '1011NB', 'latitude': 52.369488},
#  {'post_code': '1011NC', 'latitude': 52.369324},
#  {'post_code': '1011ND', 'latitude': 52.36916},
#  {'post_code': '1011NE', 'latitude': 52.37243},
#  {'post_code': '1011NG', 'latitude': 52.369858},
#  {'post_code': '1011NH', 'latitude': 52.369087},
#  {'post_code': '1011NK', 'latitude': 52.368744},
#  {'post_code': '1011NM', 'latitude': 52.369076},
#  {'post_code': '1011NN', 'latitude': 52.36905},
#  {'post_code': '1011NP', 'latitude': 52.36905},
#  {'post_code': '1011NR', 'latitude': 52.36905},
#  {'post_code': '1011NS', 'latitude': 52.36905},
#  {'post_code': '1011NV', 'latitude': 52.369114},
#  {'post_code': '1011NX', 'latitude': 52.368946},
#  {'post_code': '1011NZ', 'latitude': 52.368866},
#  {'post_code': '1011PA', 'latitude': 52.368805},
#  {'post_code': '1011PB', 'latitude': 52.368824},
#  {'post_code': '1011PC', 'latitude': 52.36875},
#  {'post_code': '1011PD', 'latitude': 52.36875},
#  {'post_code': '1011PE', 'latitude': 52.36878},
#  {'post_code': '1011PG', 'latitude': 52.368626},
#  {'post_code': '1011PL', 'latitude': 52.367367},
#  {'post_code': '1011PM', 'latitude': 52.367348},
#  {'post_code': '1011PN', 'latitude': 52.367645},
#  {'post_code': '1011PT', 'latitude': 52.367428},
#  {'post_code': '1011PV', 'latitude': 52.366405},
#  {'post_code': '1011PW', 'latitude': 52.366344},
#  {'post_code': '1011PZ', 'latitude': 52.36803},
#  {'post_code': '1011RA', 'latitude': 52.367626},
#  {'post_code': '1011RB', 'latitude': 52.367485},
#  {'post_code': '1011RC', 'latitude': 52.367393},
#  {'post_code': '1011RD', 'latitude': 52.367767},
#  {'post_code': '1011RE', 'latitude': 52.367603},
#  {'post_code': '1011RG', 'latitude': 52.367188},
#  {'post_code': '1011RH', 'latitude': 52.36716},
#  {'post_code': '1011RJ', 'latitude': 52.366154},
#  {'post_code': '1011RK', 'latitude': 52.36621},
#  {'post_code': '1011RL', 'latitude': 52.366264},
#  {'post_code': '1011RM', 'latitude': 52.366394},
#  {'post_code': '1011RN', 'latitude': 52.366394},
#  {'post_code': '1011RP', 'latitude': 52.36708},
#  {'post_code': '1011RR', 'latitude': 52.367233},
#  {'post_code': '1011RS', 'latitude': 52.36771},
#  {'post_code': '1011RT', 'latitude': 52.367695},
#  {'post_code': '1011RV', 'latitude': 52.367683},
#  {'post_code': '1011RW', 'latitude': 52.367683},
#  {'post_code': '1011RX', 'latitude': 52.36773},
#  {'post_code': '1011RZ', 'latitude': 52.367966},
#  {'post_code': '1011SB', 'latitude': 52.368183},
#  {'post_code': '1011SC', 'latitude': 52.368526},
#  {'post_code': '1011SE', 'latitude': 52.368626},
#  {'post_code': '1011SG', 'latitude': 52.368744},
#  {'post_code': '1011SK', 'latitude': 52.369488},
#  {'post_code': '1011SM', 'latitude': 52.3694},
#  {'post_code': '1011SN', 'latitude': 52.36962},
#  {'post_code': '1011SP', 'latitude': 52.369694},
#  {'post_code': '1011SR', 'latitude': 52.36944},
#  {'post_code': '1011ST', 'latitude': 52.369358},
#  {'post_code': '1011SV', 'latitude': 52.369358},
#  {'post_code': '1011SW', 'latitude': 52.369358},
#  {'post_code': '1011SX', 'latitude': 52.369358},
#  {'post_code': '1011SZ', 'latitude': 52.369358},
#  {'post_code': '1011TA', 'latitude': 52.369957},
#  {'post_code': '1011TB', 'latitude': 52.372185},
#  {'post_code': '1011TC', 'latitude': 52.371864},
#  {'post_code': '1011TD', 'latitude': 52.371296},
#  {'post_code': '1011TE', 'latitude': 52.37487},
#  {'post_code': '1011TG', 'latitude': 52.372265},
#  {'post_code': '1011TJ', 'latitude': 52.37204},
#  {'post_code': '1011TK', 'latitude': 52.36952},
#  {'post_code': '1011TL', 'latitude': 52.37202},
#  {'post_code': '1011TM', 'latitude': 52.37147},
#  {'post_code': '1011TN', 'latitude': 52.370777},
#  {'post_code': '1011TP', 'latitude': 52.370632},
#  {'post_code': '1011TR', 'latitude': 52.37094},
#  {'post_code': '1011TS', 'latitude': 52.370724},
#  {'post_code': '1011TT', 'latitude': 52.372},
#  {'post_code': '1011TV', 'latitude': 52.371628},
#  {'post_code': '1011TW', 'latitude': 52.370377},
#  {'post_code': '1011TX', 'latitude': 52.371964},
#  {'post_code': '1011TZ', 'latitude': 52.371616},
#  {'post_code': '1011VA', 'latitude': 52.370422},
#  {'post_code': '1011VB', 'latitude': 52.370335},
#  {'post_code': '1011VC', 'latitude': 52.370064},
#  {'post_code': '1011VD', 'latitude': 52.370064},
#  {'post_code': '1011VE', 'latitude': 52.370064},
#  {'post_code': '1011VG', 'latitude': 52.370064},
#  {'post_code': '1011VH', 'latitude': 52.370064},
#  {'post_code': '1011VJ', 'latitude': 52.370064},
#  {'post_code': '1011VK', 'latitude': 52.369236},
#  {'post_code': '1011VL', 'latitude': 52.36902},
#  {'post_code': '1011VM', 'latitude': 52.36858},
#  {'post_code': '1011VP', 'latitude': 52.370827},
#  {'post_code': '1011VR', 'latitude': 52.367096},
#  {'post_code': '1011VS', 'latitude': 52.366932},
#  {'post_code': '1011VT', 'latitude': 52.367302},
#  {'post_code': '1011VW', 'latitude': 52.367645},
#  {'post_code': '1011VX', 'latitude': 52.37385},
#  {'post_code': '1011VZ', 'latitude': 52.37265},
#  {'post_code': '1011WB', 'latitude': 52.370014},
#  {'post_code': '1011WC', 'latitude': 52.369556},
#  {'post_code': '1011WD', 'latitude': 52.36969},
#  {'post_code': '1011XA', 'latitude': 52.369965},
#  {'post_code': '1012AA', 'latitude': 52.379486},
#  {'post_code': '1012AB', 'latitude': 52.37847},
#  {'post_code': '1012AC', 'latitude': 52.37647},
#  {'post_code': '1012AD', 'latitude': 52.376373},
#  {'post_code': '1012AE', 'latitude': 52.376556},
#  {'post_code': '1012AG', 'latitude': 52.376472},
#  {'post_code': '1012AH', 'latitude': 52.3764},
#  {'post_code': '1012AJ', 'latitude': 52.376286},
#  {'post_code': '1012AK', 'latitude': 52.37598},
#  {'post_code': '1012AL', 'latitude': 52.37628},
#  {'post_code': '1012AM', 'latitude': 52.375668},
#  {'post_code': '1012AN', 'latitude': 52.376312},
#  {'post_code': '1012AP', 'latitude': 52.375786},
#  {'post_code': '1012AR', 'latitude': 52.37558},
#  {'post_code': '1012AS', 'latitude': 52.37504},
#  {'post_code': '1012AT', 'latitude': 52.374336},
#  {'post_code': '1012AV', 'latitude': 52.37394},
#  {'post_code': '1012AW', 'latitude': 52.373535},
#  {'post_code': '1012AX', 'latitude': 52.376286},
#  {'post_code': '1012AZ', 'latitude': 52.37574},
#  {'post_code': '1012BA', 'latitude': 52.3751},
#  {'post_code': '1012BB', 'latitude': 52.374508},
#  {'post_code': '1012BC', 'latitude': 52.37339},
#  {'post_code': '1012BD', 'latitude': 52.374336},
#  {'post_code': '1012BE', 'latitude': 52.37419},
#  {'post_code': '1012BG', 'latitude': 52.37367},
#  {'post_code': '1012BH', 'latitude': 52.37634},
#  {'post_code': '1012BJ', 'latitude': 52.37511},
#  {'post_code': '1012BK', 'latitude': 52.37497},
#  {'post_code': '1012BL', 'latitude': 52.37459},
#  {'post_code': '1012BM', 'latitude': 52.37413},
#  {'post_code': '1012BN', 'latitude': 52.37363},
#  {'post_code': '1012BP', 'latitude': 52.373287},
#  {'post_code': '1012BR', 'latitude': 52.37303},
#  {'post_code': '1012BS', 'latitude': 52.373062},
#  {'post_code': '1012BT', 'latitude': 52.373093},
#  {'post_code': '1012BV', 'latitude': 52.372566},
#  {'post_code': '1012BW', 'latitude': 52.37219},
#  {'post_code': '1012BX', 'latitude': 52.372116},
#  {'post_code': '1012BZ', 'latitude': 52.37197},
#  {'post_code': '1012CA', 'latitude': 52.37186},
#  {'post_code': '1012CB', 'latitude': 52.371647},
#  {'post_code': '1012CC', 'latitude': 52.37141},
#  {'post_code': '1012CD', 'latitude': 52.371464},
#  {'post_code': '1012CE', 'latitude': 52.371365},
#  {'post_code': '1012CG', 'latitude': 52.370804},
#  {'post_code': '1012CH', 'latitude': 52.370422},
#  {'post_code': '1012CJ', 'latitude': 52.37067},
#  {'post_code': '1012CK', 'latitude': 52.370228},
#  {'post_code': '1012CL', 'latitude': 52.37011},
#  {'post_code': '1012CM', 'latitude': 52.370003},
#  {'post_code': '1012CN', 'latitude': 52.369434},
#  {'post_code': '1012CP', 'latitude': 52.367874},
#  {'post_code': '1012CR', 'latitude': 52.373184},
#  {'post_code': '1012CS', 'latitude': 52.37249},
#  {'post_code': '1012CT', 'latitude': 52.37214},
#  {'post_code': '1012CV', 'latitude': 52.37175},
#  {'post_code': '1012CW', 'latitude': 52.3715},
#  {'post_code': '1012CX', 'latitude': 52.370804},
#  {'post_code': '1012CZ', 'latitude': 52.36961},
#  {'post_code': '1012DA', 'latitude': 52.374424},
#  {'post_code': '1012DB', 'latitude': 52.373623},
#  {'post_code': '1012DC', 'latitude': 52.372982},
#  {'post_code': '1012DD', 'latitude': 52.37252},
#  {'post_code': '1012DE', 'latitude': 52.372295},
#  {'post_code': '1012DG', 'latitude': 52.371906},
#  {'post_code': '1012DH', 'latitude': 52.37131},
#  {'post_code': '1012DJ', 'latitude': 52.37102},
#  {'post_code': '1012DK', 'latitude': 52.37067},
#  {'post_code': '1012DL', 'latitude': 52.370064},
#  {'post_code': '1012DM', 'latitude': 52.375137},
#  {'post_code': '1012DN', 'latitude': 52.374523},
#  {'post_code': '1012DP', 'latitude': 52.37426},
#  {'post_code': '1012DR', 'latitude': 52.373447},
#  {'post_code': '1012DS', 'latitude': 52.372845},
#  {'post_code': '1012DT', 'latitude': 52.372402},
#  {'post_code': '1012DV', 'latitude': 52.372086},
#  {'post_code': '1012DW', 'latitude': 52.371426},
#  {'post_code': '1012DX', 'latitude': 52.37028},
#  {'post_code': '1012DZ', 'latitude': 52.375298},
#  {'post_code': '1012EA', 'latitude': 52.374664},
#  {'post_code': '1012EB', 'latitude': 52.37377},
#  {'post_code': '1012EC', 'latitude': 52.372597},
#  {'post_code': '1012ED', 'latitude': 52.37182},
#  {'post_code': '1012EE', 'latitude': 52.371395},
#  {'post_code': '1012EG', 'latitude': 52.370945},
#  {'post_code': '1012EH', 'latitude': 52.37526},
#  {'post_code': '1012EJ', 'latitude': 52.37462},
#  {'post_code': '1012EK', 'latitude': 52.37413},
#  {'post_code': '1012EL', 'latitude': 52.373806},
#  {'post_code': '1012EM', 'latitude': 52.373386},
#  {'post_code': '1012EN', 'latitude': 52.373177},
#  {'post_code': '1012EP', 'latitude': 52.372948},
#  {'post_code': '1012ER', 'latitude': 52.372704},
#  {'post_code': '1012ES', 'latitude': 52.37257},
#  {'post_code': '1012ET', 'latitude': 52.372128},
#  {'post_code': '1012EV', 'latitude': 52.371956},
#  {'post_code': '1012EW', 'latitude': 52.371693},
#  {'post_code': '1012EX', 'latitude': 52.370945},
#  {'post_code': '1012EZ', 'latitude': 52.370018},
#  {'post_code': '1012GA', 'latitude': 52.369408},
#  {'post_code': '1012GB', 'latitude': 52.369324},
#  {'post_code': '1012GC', 'latitude': 52.36916},
#  {'post_code': '1012GD', 'latitude': 52.375763},
#  {'post_code': '1012GE', 'latitude': 52.37507},
#  {'post_code': '1012GG', 'latitude': 52.37387},
#  {'post_code': '1012GH', 'latitude': 52.37299},
#  {'post_code': '1012GJ', 'latitude': 52.372738},
#  {'post_code': '1012GK', 'latitude': 52.37206},
#  {'post_code': '1012GL', 'latitude': 52.3713},
#  {'post_code': '1012GM', 'latitude': 52.369823},
#  {'post_code': '1012GN', 'latitude': 52.37597},
#  {'post_code': '1012GP', 'latitude': 52.375797},
#  {'post_code': '1012GR', 'latitude': 52.375378},
#  {'post_code': '1012GS', 'latitude': 52.3752},
#  {'post_code': '1012GT', 'latitude': 52.375126},
#  {'post_code': '1012GV', 'latitude': 52.374783},
#  {'post_code': '1012GW', 'latitude': 52.37444},
#  {'post_code': '1012GX', 'latitude': 52.37448},
#  {'post_code': '1012GZ', 'latitude': 52.374607},
#  {'post_code': '1012HA', 'latitude': 52.373974},
#  {'post_code': '1012HB', 'latitude': 52.373848},
#  {'post_code': '1012HC', 'latitude': 52.373917},
#  {'post_code': '1012HD', 'latitude': 52.373764},
#  {'post_code': '1012HE', 'latitude': 52.3738},
#  {'post_code': '1012HG', 'latitude': 52.373245},
#  {'post_code': '1012HH', 'latitude': 52.37273},
#  {'post_code': '1012HJ', 'latitude': 52.371964},
#  {'post_code': '1012HK', 'latitude': 52.372055},
#  {'post_code': '1012HL', 'latitude': 52.372177},
#  {'post_code': '1012HM', 'latitude': 52.371513},
#  {'post_code': '1012HN', 'latitude': 52.37073},
#  {'post_code': '1012HP', 'latitude': 52.370235},
#  {'post_code': '1012HR', 'latitude': 52.369957},
#  {'post_code': '1012HS', 'latitude': 52.369762},
#  {'post_code': '1012HT', 'latitude': 52.376156},
#  {'post_code': '1012HV', 'latitude': 52.375767},
#  {'post_code': '1012HW', 'latitude': 52.375404},
#  {'post_code': '1012HX', 'latitude': 52.375084},
#  {'post_code': '1012HZ', 'latitude': 52.374783},
#  {'post_code': '1012JA', 'latitude': 52.374355},
#  {'post_code': '1012JB', 'latitude': 52.37394},
#  {'post_code': '1012JC', 'latitude': 52.37357},
#  {'post_code': '1012JD', 'latitude': 52.376247},
#  {'post_code': '1012JE', 'latitude': 52.37583},
#  {'post_code': '1012JG', 'latitude': 52.375423},
#  {'post_code': '1012JH', 'latitude': 52.37514},
#  {'post_code': '1012JJ', 'latitude': 52.374447},
#  {'post_code': '1012JK', 'latitude': 52.37365},
#  {'post_code': '1012JL', 'latitude': 52.37248},
#  {'post_code': '1012JM', 'latitude': 52.37235},
#  {'post_code': '1012JN', 'latitude': 52.375195},
#  {'post_code': '1012JP', 'latitude': 52.37526},
#  {'post_code': '1012JS', 'latitude': 52.37329},
#  {'post_code': '1012JT', 'latitude': 52.375195},
#  {'post_code': '1012JV', 'latitude': 52.374893},
#  {'post_code': '1012JW', 'latitude': 52.374603},
#  {'post_code': '1012JZ', 'latitude': 52.371212},
#  {'post_code': '1012KB', 'latitude': 52.372307},
#  {'post_code': '1012KC', 'latitude': 52.372334},
#  {'post_code': '1012KD', 'latitude': 52.371258},
#  {'post_code': '1012KE', 'latitude': 52.371933},
#  {'post_code': '1012KG', 'latitude': 52.372322},
#  {'post_code': '1012KH', 'latitude': 52.37137},
#  {'post_code': '1012KJ', 'latitude': 52.370388},
#  {'post_code': '1012KK', 'latitude': 52.372463},
#  {'post_code': '1012KL', 'latitude': 52.37078},
#  {'post_code': '1012KM', 'latitude': 52.370056},
#  {'post_code': '1012KN', 'latitude': 52.369686},
#  {'post_code': '1012KP', 'latitude': 52.369534},
#  {'post_code': '1012KR', 'latitude': 52.3724},
#  {'post_code': '1012KS', 'latitude': 52.371857},
#  {'post_code': '1012KT', 'latitude': 52.37162},
#  {'post_code': '1012KV', 'latitude': 52.371212},
#  {'post_code': '1012KW', 'latitude': 52.370796},
#  {'post_code': '1012KX', 'latitude': 52.369934},
#  {'post_code': '1012KZ', 'latitude': 52.36967},
#  {'post_code': '1012LA', 'latitude': 52.36918},
#  {'post_code': '1012LB', 'latitude': 52.36888},
#  {'post_code': '1012LC', 'latitude': 52.36862},
#  {'post_code': '1012LD', 'latitude': 52.36837},
#  {'post_code': '1012LE', 'latitude': 52.367973},
#  {'post_code': '1012LG', 'latitude': 52.377144},
#  {'post_code': '1012LH', 'latitude': 52.376446},
#  {'post_code': '1012LJ', 'latitude': 52.376415},
#  {'post_code': '1012LK', 'latitude': 52.376072},
#  {'post_code': '1012LL', 'latitude': 52.37555},
#  {'post_code': '1012LM', 'latitude': 52.375008},
#  {'post_code': '1012LN', 'latitude': 52.37436},
#  {'post_code': '1012LP', 'latitude': 52.373596},
#  {'post_code': '1012LR', 'latitude': 52.376785},
#  {'post_code': '1012LS', 'latitude': 52.376385},
#  {'post_code': '1012LT', 'latitude': 52.375652},
#  {'post_code': '1012LV', 'latitude': 52.375088},
#  {'post_code': '1012LW', 'latitude': 52.374443},
#  {'post_code': '1012LX', 'latitude': 52.374092},
#  {'post_code': '1012LZ', 'latitude': 52.378895},
#  {'post_code': '1012MA', 'latitude': 52.37827},
#  {'post_code': '1012MB', 'latitude': 52.377327},
#  {'post_code': '1012MC', 'latitude': 52.377052},
#  {'post_code': '1012MD', 'latitude': 52.37641},
#  {'post_code': '1012ME', 'latitude': 52.37568},
#  {'post_code': '1012MG', 'latitude': 52.375244},
#  {'post_code': '1012MH', 'latitude': 52.37363},
#  {'post_code': '1012MJ', 'latitude': 52.377644},
#  {'post_code': '1012MK', 'latitude': 52.378788},
#  {'post_code': '1012ML', 'latitude': 52.378456},
#  {'post_code': '1012MN', 'latitude': 52.37801},
#  {'post_code': '1012MP', 'latitude': 52.377583},
#  {'post_code': '1012MR', 'latitude': 52.377052},
#  {'post_code': '1012MS', 'latitude': 52.376305},
#  {'post_code': '1012MT', 'latitude': 52.3753},
#  {'post_code': '1012MV', 'latitude': 52.374847},
#  {'post_code': '1012MX', 'latitude': 52.374218},
#  {'post_code': '1012MZ', 'latitude': 52.37859},
#  {'post_code': '1012NA', 'latitude': 52.37823},
#  {'post_code': '1012NB', 'latitude': 52.37715},
#  {'post_code': '1012NC', 'latitude': 52.37642},
#  {'post_code': '1012ND', 'latitude': 52.37632},
#  {'post_code': '1012NE', 'latitude': 52.37576},
#  {'post_code': '1012NG', 'latitude': 52.37529},
#  {'post_code': '1012NH', 'latitude': 52.37538},
#  {'post_code': '1012NJ', 'latitude': 52.37482},
#  {'post_code': '1012NK', 'latitude': 52.37494},
#  {'post_code': '1012NL', 'latitude': 52.37424},
#  {'post_code': '1012NM', 'latitude': 52.374313},
#  {'post_code': '1012NN', 'latitude': 52.374187},
#  {'post_code': '1012NP', 'latitude': 52.373363},
#  {'post_code': '1012NR', 'latitude': 52.371418},
#  {'post_code': '1012NS', 'latitude': 52.370354},
#  {'post_code': '1012NT', 'latitude': 52.37006},
#  {'post_code': '1012NV', 'latitude': 52.369526},
#  {'post_code': '1012NW', 'latitude': 52.372128},
#  {'post_code': '1012NX', 'latitude': 52.372505},
#  {'post_code': '1012NZ', 'latitude': 52.371403},
#  {'post_code': '1012PA', 'latitude': 52.370163},
#  {'post_code': '1012PB', 'latitude': 52.369194},
#  {'post_code': '1012PC', 'latitude': 52.372513},
#  {'post_code': '1012PD', 'latitude': 52.372105},
#  {'post_code': '1012PE', 'latitude': 52.371613},
#  {'post_code': '1012PG', 'latitude': 52.371235},
#  {'post_code': '1012PH', 'latitude': 52.37073},
#  {'post_code': '1012PJ', 'latitude': 52.37036},
#  {'post_code': '1012PK', 'latitude': 52.3699},
#  {'post_code': '1012PL', 'latitude': 52.372105},
#  {'post_code': '1012PM', 'latitude': 52.370712},
#  {'post_code': '1012PN', 'latitude': 52.369446},
#  {'post_code': '1012PP', 'latitude': 52.36988},
#  {'post_code': '1012PR', 'latitude': 52.369255},
#  {'post_code': '1012PS', 'latitude': 52.37679},
#  {'post_code': '1012PT', 'latitude': 52.376095},
#  {'post_code': '1012PV', 'latitude': 52.376156},
#  {'post_code': '1012PW', 'latitude': 52.375458},
#  {'post_code': '1012PX', 'latitude': 52.375187},
#  {'post_code': '1012PZ', 'latitude': 52.374554},
#  {'post_code': '1012RA', 'latitude': 52.37598},
#  {'post_code': '1012RB', 'latitude': 52.37264},
#  {'post_code': '1012RC', 'latitude': 52.377228},
#  {'post_code': '1012RD', 'latitude': 52.376804},
#  {'post_code': '1012RE', 'latitude': 52.37568},
#  {'post_code': '1012RG', 'latitude': 52.37452},
#  {'post_code': '1012RH', 'latitude': 52.374382},
#  {'post_code': '1012RJ', 'latitude': 52.374126},
#  {'post_code': '1012RK', 'latitude': 52.372517},
#  {'post_code': '1012RL', 'latitude': 52.371655},
#  {'post_code': '1012RM', 'latitude': 52.371025},
#  {'post_code': '1012RN', 'latitude': 52.371574},
#  {'post_code': '1012RP', 'latitude': 52.37046},
#  {'post_code': '1012RR', 'latitude': 52.372993},
#  {'post_code': '1012RS', 'latitude': 52.371887},
#  {'post_code': '1012RT', 'latitude': 52.37124},
#  {'post_code': '1012RV', 'latitude': 52.370365},
#  {'post_code': '1012RW', 'latitude': 52.369717},
#  {'post_code': '1012RX', 'latitude': 52.36921},
#  {'post_code': '1012RZ', 'latitude': 52.377396},
#  {'post_code': '1012SB', 'latitude': 52.376926},
#  {'post_code': '1012SC', 'latitude': 52.376644},
#  {'post_code': '1012SE', 'latitude': 52.376266},
#  {'post_code': '1012SG', 'latitude': 52.37583},
#  {'post_code': '1012SH', 'latitude': 52.37546},
#  {'post_code': '1012SJ', 'latitude': 52.374855},
#  {'post_code': '1012SK', 'latitude': 52.376663},
#  {'post_code': '1012SL', 'latitude': 52.375877},
#  {'post_code': '1012SM', 'latitude': 52.37416},
#  {'post_code': '1012SN', 'latitude': 52.377857},
#  {'post_code': '1012SP', 'latitude': 52.377514},
#  {'post_code': '1012SR', 'latitude': 52.37667},
#  {'post_code': '1012ST', 'latitude': 52.37591},
#  {'post_code': '1012SV', 'latitude': 52.37496},
#  {'post_code': '1012SW', 'latitude': 52.378742},
#  {'post_code': '1012SX', 'latitude': 52.37818},
#  {'post_code': '1012SZ', 'latitude': 52.378155},
#  {'post_code': '1012TA', 'latitude': 52.377434},
#  {'post_code': '1012TB', 'latitude': 52.377483},
#  {'post_code': '1012TC', 'latitude': 52.376797},
#  {'post_code': '1012TD', 'latitude': 52.37677},
#  {'post_code': '1012TE', 'latitude': 52.37606},
#  {'post_code': '1012TG', 'latitude': 52.375114},
#  {'post_code': '1012TH', 'latitude': 52.37442},
#  {'post_code': '1012TJ', 'latitude': 52.373356},
#  {'post_code': '1012TK', 'latitude': 52.378895},
#  {'post_code': '1012TL', 'latitude': 52.378883},
#  {'post_code': '1012TM', 'latitude': 52.37848},
#  {'post_code': '1012TN', 'latitude': 52.37764},
#  {'post_code': '1012TP', 'latitude': 52.378124},
#  {'post_code': '1012TR', 'latitude': 52.378048},
#  {'post_code': '1012TS', 'latitude': 52.377357},
#  {'post_code': '1012TT', 'latitude': 52.376556},
#  {'post_code': '1012TV', 'latitude': 52.37638},
#  {'post_code': '1012TW', 'latitude': 52.37601},
#  {'post_code': '1012TX', 'latitude': 52.375595},
#  {'post_code': '1012TZ', 'latitude': 52.37526},
#  {'post_code': '1012VA', 'latitude': 52.375008},
#  {'post_code': '1012VB', 'latitude': 52.374363},
#  {'post_code': '1012VC', 'latitude': 52.378273},
#  {'post_code': '1012VD', 'latitude': 52.376892},
#  {'post_code': '1012VE', 'latitude': 52.37653},
#  {'post_code': '1012VG', 'latitude': 52.37616},
#  {'post_code': '1012VH', 'latitude': 52.375645},
#  {'post_code': '1012VJ', 'latitude': 52.375042},
#  {'post_code': '1012VK', 'latitude': 52.37477},
#  {'post_code': '1012VM', 'latitude': 52.37199},
#  {'post_code': '1012VN', 'latitude': 52.3728},
#  {'post_code': '1012VP', 'latitude': 52.371338},
#  {'post_code': '1012VR', 'latitude': 52.370625},
#  {'post_code': '1012VS', 'latitude': 52.369274},
#  {'post_code': '1012VT', 'latitude': 52.37304},
#  {'post_code': '1012VV', 'latitude': 52.370983},
#  {'post_code': '1012VW', 'latitude': 52.370926},
#  {'post_code': '1012VX', 'latitude': 52.370197},
#  {'post_code': '1012VZ', 'latitude': 52.37018},
#  {'post_code': '1012WB', 'latitude': 52.369614},
#  {'post_code': '1012WC', 'latitude': 52.368877},
#  {'post_code': '1012WE', 'latitude': 52.37269},
#  {'post_code': '1012WG', 'latitude': 52.371746},
#  {'post_code': '1012WH', 'latitude': 52.370934},
#  {'post_code': '1012WJ', 'latitude': 52.370514},
#  {'post_code': '1012WK', 'latitude': 52.370117},
#  {'post_code': '1012WL', 'latitude': 52.369328},
#  {'post_code': '1012WN', 'latitude': 52.36874},
#  {'post_code': '1012WP', 'latitude': 52.368168},
#  {'post_code': '1012WR', 'latitude': 52.367348},
#  {'post_code': '1012WS', 'latitude': 52.36947},
#  {'post_code': '1012WT', 'latitude': 52.36979},
#  {'post_code': '1012WV', 'latitude': 52.36916},
#  {'post_code': '1012WX', 'latitude': 52.368942},
#  {'post_code': '1012WZ', 'latitude': 52.369095},
#  {'post_code': '1012XA', 'latitude': 52.368954},
#  {'post_code': '1012XB', 'latitude': 52.368816},
#  {'post_code': '1012XC', 'latitude': 52.367973},
#  {'post_code': '1012XD', 'latitude': 52.36947},
#  {'post_code': '1012XE', 'latitude': 52.36877},
#  {'post_code': '1012XG', 'latitude': 52.368305},
#  {'post_code': '1012XH', 'latitude': 52.36791},
#  {'post_code': '1012XJ', 'latitude': 52.36741},
#  {'post_code': '1012XK', 'latitude': 52.368732},
#  {'post_code': '1012XL', 'latitude': 52.368374},
#  {'post_code': '1012XM', 'latitude': 52.36855},
#  {'post_code': '1012XN', 'latitude': 52.36791},
#  {'post_code': '1012XP', 'latitude': 52.36759},
#  {'post_code': '1012XR', 'latitude': 52.367966},
#  {'post_code': '1012XS', 'latitude': 52.367653},
#  {'post_code': '1012XT', 'latitude': 52.368958},
#  {'post_code': '1012XV', 'latitude': 52.36769},
#  {'post_code': '1012XW', 'latitude': 52.37479},
#  {'post_code': '1012XX', 'latitude': 52.368626},
#  {'post_code': '1012XZ', 'latitude': 52.373672},
#  {'post_code': '1012ZA', 'latitude': 52.369064},
#  {'post_code': '1012ZD', 'latitude': 52.3688},
#  {'post_code': '1012ZE', 'latitude': 52.368557},
#  {'post_code': '1012ZG', 'latitude': 52.36831},
#  {'post_code': '1012ZH', 'latitude': 52.37582},
#  {'post_code': '1012ZJ', 'latitude': 52.37547},
#  {'post_code': '1012ZK', 'latitude': 52.374454},
#  {'post_code': '1012ZL', 'latitude': 52.372417},
#  {'post_code': '1012ZX', 'latitude': 52.37013},
#  {'post_code': '1013AA', 'latitude': 52.382595},
#  {'post_code': '1013AC', 'latitude': 52.398224},
#  {'post_code': '1013AD', 'latitude': 52.38356},
#  {'post_code': '1013AE', 'latitude': 52.387722},
#  {'post_code': '1013AG', 'latitude': 52.380714},
#  {'post_code': '1013AJ', 'latitude': 52.38862},
#  {'post_code': '1013AK', 'latitude': 52.396374},
#  {'post_code': '1013AL', 'latitude': 52.39026},
#  {'post_code': '1013AM', 'latitude': 52.396606},
#  {'post_code': '1013AP', 'latitude': 52.395985},
#  {'post_code': '1013AR', 'latitude': 52.39839},
#  {'post_code': '1013AS', 'latitude': 52.390835},
#  {'post_code': '1013AV', 'latitude': 52.38727},
#  {'post_code': '1013AW', 'latitude': 52.39252},
#  {'post_code': '1013AZ', 'latitude': 52.383327},
#  {'post_code': '1013BB', 'latitude': 52.39798},
#  {'post_code': '1013BC', 'latitude': 52.397903},
#  {'post_code': '1013BD', 'latitude': 52.394394},
#  {'post_code': '1013BE', 'latitude': 52.395504},
#  {'post_code': '1013BG', 'latitude': 52.394176},
#  {'post_code': '1013BH', 'latitude': 52.38341},
#  {'post_code': '1013BJ', 'latitude': 52.39911},
#  {'post_code': '1013BK', 'latitude': 52.401714},
#  {'post_code': '1013BL', 'latitude': 52.40269},
#  {'post_code': '1013BM', 'latitude': 52.403183},
#  {'post_code': '1013BN', 'latitude': 52.403465},
#  {'post_code': '1013BP', 'latitude': 52.385384},
#  {'post_code': '1013BR', 'latitude': 52.384296},
#  {'post_code': '1013BS', 'latitude': 52.41166},
#  {'post_code': '1013BT', 'latitude': 52.40309},
#  {'post_code': '1013BV', 'latitude': 52.38557},
#  {'post_code': '1013BW', 'latitude': 52.387444},
#  {'post_code': '1013BX', 'latitude': 52.38552},
#  {'post_code': '1013BZ', 'latitude': 52.388382},
#  {'post_code': '1013CA', 'latitude': 52.388973},
#  {'post_code': '1013CB', 'latitude': 52.389206},
#  {'post_code': '1013CC', 'latitude': 52.389397},
#  {'post_code': '1013CD', 'latitude': 52.38981},
#  {'post_code': '1013CE', 'latitude': 52.390156},
#  {'post_code': '1013CG', 'latitude': 52.38651},
#  {'post_code': '1013CH', 'latitude': 52.389286},
#  {'post_code': '1013CJ', 'latitude': 52.389217},
#  {'post_code': '1013CK', 'latitude': 52.38962},
#  {'post_code': '1013CL', 'latitude': 52.39016},
#  {'post_code': '1013CM', 'latitude': 52.390312},
#  {'post_code': '1013CN', 'latitude': 52.39007},
#  {'post_code': '1013CP', 'latitude': 52.39},
#  {'post_code': '1013CR', 'latitude': 52.39073},
#  {'post_code': '1013CS', 'latitude': 52.388985},
#  {'post_code': '1013CT', 'latitude': 52.387646},
#  {'post_code': '1013CW', 'latitude': 52.38756},
#  {'post_code': '1013CX', 'latitude': 52.395622},
#  {'post_code': '1013CZ', 'latitude': 52.396774},
#  {'post_code': '1013DA', 'latitude': 52.383224},
#  {'post_code': '1013DB', 'latitude': 52.38367},
#  {'post_code': '1013DC', 'latitude': 52.383232},
#  {'post_code': '1013DD', 'latitude': 52.383797},
#  {'post_code': '1013DE', 'latitude': 52.38354},
#  {'post_code': '1013DG', 'latitude': 52.3837},
#  {'post_code': '1013DH', 'latitude': 52.38353},
#  {'post_code': '1013DJ', 'latitude': 52.38431},
#  {'post_code': '1013DK', 'latitude': 52.384563},
#  {'post_code': '1013DL', 'latitude': 52.385056},
#  {'post_code': '1013DM', 'latitude': 52.384842},
#  {'post_code': '1013DN', 'latitude': 52.384747},
#  {'post_code': '1013DP', 'latitude': 52.3824},
#  {'post_code': '1013DR', 'latitude': 52.388588},
#  {'post_code': '1013DS', 'latitude': 52.38875},
#  {'post_code': '1013DT', 'latitude': 52.391914},
#  {'post_code': '1013DV', 'latitude': 52.390976},
#  {'post_code': '1013DW', 'latitude': 52.391243},
#  {'post_code': '1013DX', 'latitude': 52.3916},
#  {'post_code': '1013DZ', 'latitude': 52.392418},
#  {'post_code': '1013EA', 'latitude': 52.37988},
#  {'post_code': '1013EB', 'latitude': 52.37994},
#  {'post_code': '1013EC', 'latitude': 52.380047},
#  {'post_code': '1013ED', 'latitude': 52.380222},
#  {'post_code': '1013EE', 'latitude': 52.38037},
#  {'post_code': '1013EG', 'latitude': 52.380398},
#  {'post_code': '1013EH', 'latitude': 52.379234},
#  {'post_code': '1013EJ', 'latitude': 52.37942},
#  {'post_code': '1013EK', 'latitude': 52.37978},
#  {'post_code': '1013EL', 'latitude': 52.38002},
#  {'post_code': '1013EM', 'latitude': 52.38051},
#  {'post_code': '1013EN', 'latitude': 52.380863},
#  {'post_code': '1013EP', 'latitude': 52.381058},
#  {'post_code': '1013ER', 'latitude': 52.379353},
#  {'post_code': '1013ES', 'latitude': 52.379913},
#  {'post_code': '1013ET', 'latitude': 52.380306},
#  {'post_code': '1013EV', 'latitude': 52.38044},
#  {'post_code': '1013EW', 'latitude': 52.380634},
#  {'post_code': '1013EX', 'latitude': 52.380913},
#  {'post_code': '1013EZ', 'latitude': 52.38125},
#  {'post_code': '1013GA', 'latitude': 52.379524},
#  {'post_code': '1013GB', 'latitude': 52.37997},
#  {'post_code': '1013GC', 'latitude': 52.379635},
#  {'post_code': '1013GD', 'latitude': 52.37969},
#  {'post_code': '1013GE', 'latitude': 52.38026},
#  {'post_code': '1013GG', 'latitude': 52.379963},
#  {'post_code': '1013GH', 'latitude': 52.380238},
#  {'post_code': '1013GJ', 'latitude': 52.380886},
#  {'post_code': '1013GK', 'latitude': 52.38111},
#  {'post_code': '1013GL', 'latitude': 52.38037},
#  {'post_code': '1013GM', 'latitude': 52.380978},
#  {'post_code': '1013GN', 'latitude': 52.38186},
#  {'post_code': '1013GP', 'latitude': 52.381096},
#  {'post_code': '1013GR', 'latitude': 52.38115},
#  {'post_code': '1013GS', 'latitude': 52.382164},
#  {'post_code': '1013GT', 'latitude': 52.381207},
#  {'post_code': '1013GW', 'latitude': 52.379055},
#  {'post_code': '1013GX', 'latitude': 52.3793},
#  {'post_code': '1013GZ', 'latitude': 52.379734},
#  {'post_code': '1013HA', 'latitude': 52.38009},
#  {'post_code': '1013HB', 'latitude': 52.38089},
#  {'post_code': '1013HC', 'latitude': 52.38117},
#  {'post_code': '1013HD', 'latitude': 52.38148},
#  {'post_code': '1013HE', 'latitude': 52.3819},
#  {'post_code': '1013HG', 'latitude': 52.38273},
#  {'post_code': '1013HH', 'latitude': 52.38374},
#  {'post_code': '1013HK', 'latitude': 52.383183},
#  {'post_code': '1013HL', 'latitude': 52.38328},
#  {'post_code': '1013HM', 'latitude': 52.383682},
#  {'post_code': '1013HN', 'latitude': 52.38467},
#  {'post_code': '1013HP', 'latitude': 52.384216},
#  {'post_code': '1013HR', 'latitude': 52.38458},
#  {'post_code': '1013HS', 'latitude': 52.384388},
#  {'post_code': '1013HT', 'latitude': 52.384293},
#  {'post_code': '1013HV', 'latitude': 52.384605},
#  {'post_code': '1013HW', 'latitude': 52.383705},
#  {'post_code': '1013HX', 'latitude': 52.38271},
#  {'post_code': '1013HZ', 'latitude': 52.38231},
#  {'post_code': '1013JA', 'latitude': 52.382423},
#  {'post_code': '1013JB', 'latitude': 52.38322},
#  {'post_code': '1013JC', 'latitude': 52.381687},
#  {'post_code': '1013JD', 'latitude': 52.381943},
#  {'post_code': '1013JE', 'latitude': 52.382282},
#  {'post_code': '1013JG', 'latitude': 52.382774},
#  {'post_code': '1013JH', 'latitude': 52.38316},
#  {'post_code': '1013JJ', 'latitude': 52.383408},
#  {'post_code': '1013JK', 'latitude': 52.38384},
#  {'post_code': '1013JL', 'latitude': 52.38124},
#  {'post_code': '1013JM', 'latitude': 52.38209},
#  {'post_code': '1013JN', 'latitude': 52.38266},
#  {'post_code': '1013JP', 'latitude': 52.38307},
#  {'post_code': '1013JR', 'latitude': 52.383312},
#  {'post_code': '1013JS', 'latitude': 52.381424},
#  {'post_code': '1013JT', 'latitude': 52.381752},
#  {'post_code': '1013JV', 'latitude': 52.38227},
#  {'post_code': '1013JW', 'latitude': 52.382965},
#  {'post_code': '1013JX', 'latitude': 52.383625},
#  {'post_code': '1013JZ', 'latitude': 52.381645},
#  {'post_code': '1013KA', 'latitude': 52.381844},
#  {'post_code': '1013KB', 'latitude': 52.382095},
#  {'post_code': '1013KC', 'latitude': 52.382477},
#  {'post_code': '1013KD', 'latitude': 52.38295},
#  {'post_code': '1013KE', 'latitude': 52.3833},
#  {'post_code': '1013KG', 'latitude': 52.383514},
#  {'post_code': '1013KH', 'latitude': 52.38381},
#  {'post_code': '1013KJ', 'latitude': 52.38281},
#  {'post_code': '1013KK', 'latitude': 52.383884},
#  {'post_code': '1013KL', 'latitude': 52.383987},
#  {'post_code': '1013KM', 'latitude': 52.38379},
#  {'post_code': '1013KN', 'latitude': 52.38389},
#  {'post_code': '1013KP', 'latitude': 52.384876},
#  {'post_code': '1013KR', 'latitude': 52.38603},
#  {'post_code': '1013KS', 'latitude': 52.38321},
#  {'post_code': '1013KT', 'latitude': 52.387455},
#  {'post_code': '1013KV', 'latitude': 52.385437},
#  {'post_code': '1013KW', 'latitude': 52.387245},
#  {'post_code': '1013KX', 'latitude': 52.38553},
#  {'post_code': '1013LA', 'latitude': 52.387676},
#  {'post_code': '1013LB', 'latitude': 52.387215},
#  {'post_code': '1013LC', 'latitude': 52.388645},
#  {'post_code': '1013LD', 'latitude': 52.388596},
#  {'post_code': '1013LE', 'latitude': 52.38393},
#  {'post_code': '1013LG', 'latitude': 52.384644},
#  {'post_code': '1013LH', 'latitude': 52.385605},
#  {'post_code': '1013LJ', 'latitude': 52.38548},
#  {'post_code': '1013LL', 'latitude': 52.385643},
#  {'post_code': '1013LM', 'latitude': 52.38642},
#  {'post_code': '1013LN', 'latitude': 52.385242},
#  {'post_code': '1013LP', 'latitude': 52.384884},
#  {'post_code': '1013LR', 'latitude': 52.385628},
#  {'post_code': '1013LT', 'latitude': 52.385525},
#  {'post_code': '1013LV', 'latitude': 52.386684},
#  {'post_code': '1013LX', 'latitude': 52.38566},
#  {'post_code': '1013LZ', 'latitude': 52.385777},
#  {'post_code': '1013MA', 'latitude': 52.3863},
#  {'post_code': '1013MB', 'latitude': 52.386776},
#  {'post_code': '1013MC', 'latitude': 52.387897},
#  {'post_code': '1013MD', 'latitude': 52.387955},
#  {'post_code': '1013ME', 'latitude': 52.386585},
#  {'post_code': '1013MG', 'latitude': 52.386322},
#  {'post_code': '1013MH', 'latitude': 52.387375},
#  {'post_code': '1013MJ', 'latitude': 52.3859},
#  {'post_code': '1013MK', 'latitude': 52.38634},
#  {'post_code': '1013ML', 'latitude': 52.387493},
#  {'post_code': '1013MM', 'latitude': 52.385056},
#  {'post_code': '1013MN', 'latitude': 52.387684},
#  {'post_code': '1013MP', 'latitude': 52.390114},
#  {'post_code': '1013MR', 'latitude': 52.389652},
#  {'post_code': '1013MS', 'latitude': 52.38788},
#  {'post_code': '1013MT', 'latitude': 52.387165},
#  {'post_code': '1013MV', 'latitude': 52.386436},
#  {'post_code': '1013MX', 'latitude': 52.390656},
#  {'post_code': '1013MZ', 'latitude': 52.387802},
#  {'post_code': '1013NA', 'latitude': 52.386837},
#  {'post_code': '1013NB', 'latitude': 52.38717},
#  {'post_code': '1013NC', 'latitude': 52.387257},
#  {'post_code': '1013ND', 'latitude': 52.38755},
#  {'post_code': '1013NE', 'latitude': 52.387882},
#  {'post_code': '1013NG', 'latitude': 52.388325},
#  {'post_code': '1013NH', 'latitude': 52.38974},
#  {'post_code': '1013NJ', 'latitude': 52.38928},
#  {'post_code': '1013NK', 'latitude': 52.38889},
#  {'post_code': '1013NL', 'latitude': 52.38907},
#  {'post_code': '1013NM', 'latitude': 52.38878},
#  {'post_code': '1013NN', 'latitude': 52.38872},
#  {'post_code': '1013NP', 'latitude': 52.389244},
#  {'post_code': '1013NR', 'latitude': 52.389256},
#  {'post_code': '1013NS', 'latitude': 52.38919},
#  {'post_code': '1013NT', 'latitude': 52.388866},
#  {'post_code': '1013NV', 'latitude': 52.38906},
#  {'post_code': '1013NX', 'latitude': 52.389183},
#  {'post_code': '1013NZ', 'latitude': 52.389225},
#  {'post_code': '1013PA', 'latitude': 52.38925},
#  {'post_code': '1013PB', 'latitude': 52.389336},
#  {'post_code': '1013PC', 'latitude': 52.389343},
#  {'post_code': '1013PD', 'latitude': 52.38935},
#  {'post_code': '1013PE', 'latitude': 52.389515},
#  {'post_code': '1013PG', 'latitude': 52.389503},
#  {'post_code': '1013PH', 'latitude': 52.389515},
#  {'post_code': '1013PJ', 'latitude': 52.3897},
#  {'post_code': '1013PK', 'latitude': 52.389385},
#  {'post_code': '1013PL', 'latitude': 52.3896},
#  {'post_code': '1013PM', 'latitude': 52.38965},
#  {'post_code': '1013PN', 'latitude': 52.389317},
#  {'post_code': '1013PP', 'latitude': 52.389465},
#  {'post_code': '1013PR', 'latitude': 52.389458},
#  {'post_code': '1013PS', 'latitude': 52.38971},
#  {'post_code': '1013PT', 'latitude': 52.389755},
#  {'post_code': '1013PV', 'latitude': 52.389717},
#  {'post_code': '1013PW', 'latitude': 52.39067},
#  {'post_code': '1013PX', 'latitude': 52.390854},
#  {'post_code': '1013RA', 'latitude': 52.39109},
#  {'post_code': '1013RB', 'latitude': 52.390965},
#  {'post_code': '1013RC', 'latitude': 52.391037},
#  {'post_code': '1013RD', 'latitude': 52.391087},
#  {'post_code': '1013RE', 'latitude': 52.39114},
#  {'post_code': '1013RG', 'latitude': 52.391167},
#  {'post_code': '1013RH', 'latitude': 52.391216},
#  {'post_code': '1013RJ', 'latitude': 52.389935},
#  {'post_code': '1013RK', 'latitude': 52.39024},
#  {'post_code': '1013RL', 'latitude': 52.390274},
#  {'post_code': '1013RM', 'latitude': 52.39029},
#  {'post_code': '1013RN', 'latitude': 52.390316},
#  {'post_code': '1013RP', 'latitude': 52.390343},
#  {'post_code': '1013RR', 'latitude': 52.3862},
#  {'post_code': '1013RS', 'latitude': 52.387424},
#  {'post_code': '1013RT', 'latitude': 52.387444},
#  {'post_code': '1013RV', 'latitude': 52.387444},
#  {'post_code': '1013RW', 'latitude': 52.38753},
#  {'post_code': '1013RX', 'latitude': 52.38988},
#  {'post_code': '1013RZ', 'latitude': 52.390583},
#  {'post_code': '1013SB', 'latitude': 52.390755},
#  {'post_code': '1013SC', 'latitude': 52.39128},
#  {'post_code': '1013SE', 'latitude': 52.391586},
#  {'post_code': '1013SG', 'latitude': 52.39208},
#  {'post_code': '1013SH', 'latitude': 52.392384},
#  {'post_code': '1013SJ', 'latitude': 52.38879},
#  {'post_code': '1013SK', 'latitude': 52.388744},
#  {'post_code': '1013SL', 'latitude': 52.388844},
#  {'post_code': '1013SM', 'latitude': 52.38908},
#  {'post_code': '1013SN', 'latitude': 52.38895},
#  {'post_code': '1013SP', 'latitude': 52.389122},
#  {'post_code': '1013SR', 'latitude': 52.387573},
#  {'post_code': '1013ST', 'latitude': 52.388718},
#  {'post_code': '1013SV', 'latitude': 52.386593},
#  {'post_code': '1013SW', 'latitude': 52.387012},
#  {'post_code': '1013SX', 'latitude': 52.38753},
#  {'post_code': '1013SZ', 'latitude': 52.387917},
#  {'post_code': '1013TA', 'latitude': 52.38919},
#  {'post_code': '1013TB', 'latitude': 52.389587},
#  {'post_code': '1013TC', 'latitude': 52.389927},
#  {'post_code': '1013TD', 'latitude': 52.390377},
#  {'post_code': '1013TE', 'latitude': 52.390743},
#  {'post_code': '1013TG', 'latitude': 52.391148},
#  {'post_code': '1013TH', 'latitude': 52.389313},
#  {'post_code': '1013TJ', 'latitude': 52.390057},
#  {'post_code': '1013TK', 'latitude': 52.39097},
#  {'post_code': '1013TL', 'latitude': 52.39053},
#  {'post_code': '1013TM', 'latitude': 52.39031},
#  {'post_code': '1013TN', 'latitude': 52.390697},
#  {'post_code': '1013TP', 'latitude': 52.390297},
#  {'post_code': '1013TR', 'latitude': 52.392002},
#  {'post_code': '1013TS', 'latitude': 52.39121},
#  {'post_code': '1013TX', 'latitude': 52.39054},
#  {'post_code': '1013VB', 'latitude': 52.389748},
#  {'post_code': '1013VD', 'latitude': 52.389023},
#  {'post_code': '1013VG', 'latitude': 52.38981},
#  {'post_code': '1013VH', 'latitude': 52.389927},
#  {'post_code': '1013VJ', 'latitude': 52.390285},
#  {'post_code': '1013VK', 'latitude': 52.390644},
#  {'post_code': '1013VL', 'latitude': 52.390625},
#  {'post_code': '1013VM', 'latitude': 52.38802},
#  {'post_code': '1013VN', 'latitude': 52.388237},
#  {'post_code': '1013VP', 'latitude': 52.387978},
#  {'post_code': '1013VR', 'latitude': 52.389015},
#  {'post_code': '1013VS', 'latitude': 52.38915},
#  {'post_code': '1013VT', 'latitude': 52.389427},
#  {'post_code': '1013VV', 'latitude': 52.389572},
#  {'post_code': '1013VW', 'latitude': 52.388668},
#  {'post_code': '1013VX', 'latitude': 52.389378},
#  {'post_code': '1013VZ', 'latitude': 52.3895},
#  {'post_code': '1013WB', 'latitude': 52.389732},
#  {'post_code': '1013WC', 'latitude': 52.39044},
#  {'post_code': '1013WD', 'latitude': 52.391094},
#  {'post_code': '1013WE', 'latitude': 52.389973},
#  {'post_code': '1013WG', 'latitude': 52.39018},
#  {'post_code': '1013WH', 'latitude': 52.391205},
#  {'post_code': '1013WJ', 'latitude': 52.392014},
#  ...]
